# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat
from scipy.signal import butter, filtfilt, detrend
from scipy.interpolate import interp1d
import torch
import torch.nn as nn
import torch.optim as optim
import mne
from torchdiffeq import odeint_adjoint
import time
import sys
import gc
from scipy.signal import detrend
from scipy.integrate import solve_ivp
import torch.nn.functional as F
from tqdm.notebook import tqdm
from numpy.fft import fft, ifft
from scipy.signal import medfilt
from torchdiffeq import odeint
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# extra functions 
def fft(data,sfreq):
    n_samples = data.shape[0]
    fft_vals = np.fft.rfft(data)
    fft_freqs = np.fft.rfftfreq(n_samples, d=1/sfreq)
    fft_amplitude = np.abs(fft_vals)
    return fft_freqs, fft_amplitude

def bandpass_filter(data, lowcut, highcut, fs, order=4):
    b, a = butter(order, [lowcut/(0.5*fs), highcut/(0.5*fs)], btype='band')
    filtered_data = filtfilt(b, a, data)
    return filtered_data

def get_median_filter_width(sampling_rate, duration):
    res = int( sampling_rate*duration )
    res += ((res%2) - 1) 
    return res

def filter_signal(X):
    global mfa
    X0 = X  
    for mi in range(0,len(mfa)):
        X0 = medfilt(X0,mfa[mi]) # apply median filter one by one on top of each other
    X0 = np.subtract(X,X0)  
    return X0

# %%
fs = 100  
total_duration = 15
train_duration = 10
test_duration = 5
t_train = np.arange(0, train_duration, 1/fs)
t_test = np.arange(train_duration, total_duration, 1/fs)
t_full = np.arange(0, total_duration, 1/fs)
fs_hidden = fs
file_new_raw = '/home/shobs/Desktop/DDP/transdef_mf2pt2_rest_raw.fif'
raw = mne.io.read_raw_fif(file_new_raw, preload=False)
data, times = raw[322, 2000:17000]
ecg_data = -data[0]
mat = loadmat("/home/shobs/Desktop/DDP/scout_id_309.mat")
eeg_data = mat['Value']
eeg_data = eeg_data[:, 2000:17000]
sc_data = loadmat('/home/shobs/Desktop/DDP/SC_CC120309-27.mat')
sc_matrix = sc_data["sc"]
max_val = np.max(sc_matrix)
Sw_all = (sc_matrix / max_val) * 0.01 if max_val > 0 else sc_matrix

non_zero_indices_per_row = [np.nonzero(Sw_all[i, :])[0] for i in range(Sw_all.shape[0])]

def preprocess_signal(signal, fs=1000, lowcut=1.5, highcut=30):
    detrended = detrend(signal)
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(4, [low, high], btype='band')
    filtered = filtfilt(b, a, detrended)
    normalized = (filtered - np.mean(filtered)) / np.std(filtered)
    return normalized

ecg_detrended = detrend(ecg_data, type='linear')
ecg_data = ecg_detrended

fs,Fs,lowcut,highcut,order = 1000,1000,0.65,40.0,4
filtered_ecg = bandpass_filter(ecg_data, lowcut, highcut, fs, order)

ms_flt_array = [0.2,0.6]    
mfa = np.zeros(len(ms_flt_array), dtype='int')
for i in range(0, len(ms_flt_array)):
    mfa[i] = get_median_filter_width(Fs,ms_flt_array[i])
signal_flt = filter_signal(filtered_ecg)

# step 4 - Normalize the filtered signal to [0, 1]
normalized_ecg_basecorrect = ((signal_flt - np.min(signal_flt)) / (np.max(signal_flt) - np.min(signal_flt))) 
ecg_processed_1k=normalized_ecg_basecorrect
eeg_processed_1k = np.array([preprocess_signal(row, fs=1000, lowcut=1.5, highcut=20) for row in eeg_data])
ecg_processed = ecg_processed_1k[::10]
eeg_processed = eeg_processed_1k[:, ::10]
# Out:
# Opening raw data file /home/shobs/Desktop/DDP/transdef_mf2pt2_rest_raw.fif...
#     Range : 114000 ... 680999 =    114.000 ...   680.999 secs
# Ready.

# %%
train_samples = len(t_train)
test_samples = len(t_test)

ecg_train = ecg_processed[:train_samples]
ecg_test = ecg_processed[train_samples:train_samples + test_samples]

eeg_train = eeg_processed[:, :train_samples]
eeg_test = eeg_processed[:, train_samples:train_samples + test_samples]

print(len(ecg_train), len(ecg_test), eeg_train.shape, eeg_test.shape)
# Out:
# 1000 500 (68, 1000) (68, 500)

# %%
target_idx = 0
target_signal_train = eeg_train[target_idx]
target_signal_full = eeg_processed[target_idx] 

D_function = interp1d(t_train, target_signal_train, kind='linear', bounds_error=False, fill_value=0.0)

def simulate_coupled_oscillators(T=2, dt=0.01, alpha=1, omega1=5.01, omega2=5.1,
                                 A_init=0.0001, theta_init=3.14, n=1.0, modulation=None):
    N = int(np.round(T / dt))
    r1, r2, phi1, phi2 = 1.0, 1.0, 0.0, 0.0
    A12, A21 = A_init, A_init
    theta12, theta21 = theta_init, theta_init
    R1, R2, Phi1, Phi2 = np.zeros(N), np.zeros(N), np.zeros(N), np.zeros(N)

    for i in range(N):
        R1[i], R2[i], Phi1[i], Phi2[i] = r1, r2, phi1, phi2
        coupling12 = A12 * r2 * np.cos(theta12 + n * (phi2 - phi1))
        coupling21 = A21 * r1 * np.cos(theta21 + n * (phi1 - phi2))
        if modulation is not None:
            dr1 = alpha * r1 - r1**3 + coupling12 + 0.1 * modulation[i, 0]
            dr2 = alpha * r2 - r2**3 + coupling21 + 0.1 * modulation[i, 1]
        else:
            dr1 = alpha * r1 - r1**3 + coupling12
            dr2 = alpha * r2 - r2**3 + coupling21
        dphi1 = omega1 + A12 * r2 / (r1 + 1e-9) * np.sin(theta12 + n * (phi2 - phi1))
        dphi2 = omega2 + A21 * r1 / (r2 + 1e-9) * np.sin(theta21 + n * (phi1 - phi2))
        r1 += dr1 * dt
        r2 += dr2 * dt
        phi1 += dphi1 * dt
        phi2 += dphi2 * dt

    return np.stack((R1*np.cos(Phi1), R1*np.sin(Phi1), R2*np.cos(Phi2), R2*np.sin(Phi2)), axis=1)

def get_random_frequencies(num_regions, osc_per_region, low=1, high=20, seed=None):
    if seed is not None:
        np.random.seed(seed)
    total = num_regions * osc_per_region
    freqs_hz = np.random.uniform(low, high, total)
    return 2 * np.pi * freqs_hz

def expand_structural_connectivity(Sc_region, osc_per_region, intra_value=0.0001, seed=None):
    if seed is not None:
        np.random.seed(seed)
    num_regions = Sc_region.shape[0]
    N = num_regions * osc_per_region
    Sc_full = np.zeros((N, N))
    for i in range(num_regions):
        for j in range(num_regions):
            si, ei = i * osc_per_region, (i + 1) * osc_per_region
            sj, ej = j * osc_per_region, (j + 1) * osc_per_region
            if i == j:
                Sc_full[si:ei, sj:ej] = intra_value
            else:
                rand_block = np.random.rand(osc_per_region, osc_per_region)
                rand_block *= Sc_region[i, j] / (rand_block.sum() + 1e-9)
                Sc_full[si:ei, sj:ej] = rand_block
    np.fill_diagonal(Sc_full, 0.0)
    return Sc_full

def reset_weights(m):
    if hasattr(m, 'reset_parameters'):
        m.reset_parameters()


class HeartModel(nn.Module):
    def __init__(self, input_dim=4, hidden_dim=100, feature_dim=50, output_dim=1):
        super().__init__()
        self.feature_extractor = nn.Sequential(
            nn.Linear(input_dim, hidden_dim), nn.Sigmoid(),
            nn.Linear(hidden_dim, hidden_dim), nn.Sigmoid(),
            nn.Linear(hidden_dim, feature_dim),
        )
        self.output_layer = nn.Linear(feature_dim, output_dim)

    def forward(self, x):
        features = self.feature_extractor(x)
        return self.output_layer(features)

    def get_features(self, x):
        return self.feature_extractor(x)

# %%
class OscillatorODEFunc(nn.Module):
    def __init__(self, N_osc, mu, k, omega, C, theta, device="cpu"):
        super().__init__()
        self.N_osc = N_osc
        self.mu = mu # nn.Parameter
        self.k = k   # nn.Parameter

        self.register_buffer("omega", omega) # nn.Parameter from OscillatorLayer
        self.register_buffer("C", C)
        self.register_buffer("theta", theta)

        # Internal clamps for numerical stability
        self.r_min = 0.001
        self.r_max = 2.0
        #self.power_min = 1e-6
        #self.power_max = 2.0
        self.phase_clip = 2*np.pi

        # This will be updated by the OscillatorLayer.forward before calling odeint
        # It should be (B, N_osc, 1) or (1, N_osc, 1) if B=1
        self.input_f = None

    def forward(self, t, state):
        # state is (B, N_osc * 2) -> split into (B, N_osc) for r and phi
        B = state.shape[0]
        N_osc = self.N_osc

        r = state[:, :N_osc].unsqueeze(-1)  # (B, N_osc, 1)
        phi = state[:, N_osc:].unsqueeze(-1) # (B, N_osc, 1)

        # Constant input_f for the entire ODE integration
        input_f = self.input_f # (B, N_osc, 1)

        omega_i = self.omega.unsqueeze(0).unsqueeze(-1) # (1, N_osc, 1)
        omega_j = self.omega.unsqueeze(0).unsqueeze(1) # (1, 1, N_osc)

        #rho = omega_i / (omega_j + 1e-8) # (1, N_osc, N_osc)
        #rho= torch.clamp(rho, 0.1,0.6)
        C = self.C.unsqueeze(0) # (1, N_osc, N_osc)
        theta = self.theta.unsqueeze(0) # (1, N_osc, N_osc)

        phi_i = phi # (B, N_osc, 1)
        phi_j = phi.transpose(1, 2) # (B, 1, N_osc)

        # --- Phase term ---
        phase_term = phi_j/omega_j - phi_i/omega_i + theta/(omega_i*omega_j) # (B, N_osc, N_osc)

        # Clamp large phase excursions (numerical safety)
        phase_term = torch.clamp(
            phase_term,
            -self.phase_clip,
            self.phase_clip
        )

        # --- Power amplitude (Log-Domain Safe) ---
        r_j = r.transpose(1, 2) # (B, 1, N_osc)
        r_j_clamped = torch.clamp(r_j, self.r_min, self.r_max)

        #log_r_j = torch.log(r_j_clamped)
        #r_power = torch.exp(rho * log_r_j) # (B, N_osc, N_osc)

        # Clamp power explosion
        r_safe = torch.clamp(r, self.r_min, self.r_max) # (B, N_osc, 1)
        r= r_safe

        coupling_r = self.k * torch.sum(
            C * r_j * torch.cos(omega_i*(phase_term)),
            dim=-1,
            keepdim=True
        ) # (B, N_osc, 1)



        coupling_phi = self.k * torch.sum(
            C * (r_j/r_safe) * torch.sin(omega_i*(phase_term)),
            dim=-1,
            keepdim=True
        ) # (B, N_osc, 1)

        dr_dt = (self.mu - r**2) * r + coupling_r + input_f # (B, N_osc, 1)
        dphi_dt = self.omega.unsqueeze(0).unsqueeze(-1) + coupling_phi # (B, N_osc, 1)

        return torch.cat([
            dr_dt.squeeze(-1),
            dphi_dt.squeeze(-1)
        ], dim=-1)


class OscillatorLayer(nn.Module):
    def __init__(self, N_osc=16, T=2.0, fs=100, device="cpu",
                 coupling_sparsity=0.3, seed=42):

        super().__init__()

        self.N_osc = N_osc
        self.T = T
        self.fs = fs
        self.dt = 1.0 / fs

        torch.manual_seed(seed)

        freqs = 2.0 + torch.rand(N_osc, device=device) * 8.0

        # Initialize learnable parameters
        self.mu_param = nn.Parameter(torch.tensor(1.0, device=device)) # Mu can be a learnable parameter
        self.k_param = nn.Parameter(torch.tensor(0.01, device=device)) # k can be a learnable parameter
        self.omega_param = nn.Parameter(2 * torch.pi * freqs) # omega is learnable

        # C and theta are structural, so typically not learned, but passed as buffers
        mask = torch.rand(N_osc, N_osc, device=device) > coupling_sparsity
        mask.fill_diagonal_(False)
        C_val = torch.rand(N_osc, N_osc, device=device) * 0.02
        self.C_buffer = C_val * mask.float()

        theta_val = torch.zeros(N_osc, N_osc, device=device)
        theta_val.fill_diagonal_(0.0)
        self.theta_buffer = theta_val

        # Instantiate the ODE function
        self.ode_func = OscillatorODEFunc(
            N_osc=N_osc,
            mu=self.mu_param,
            k=self.k_param,
            omega=self.omega_param,
            C=self.C_buffer,
            theta=self.theta_buffer,
            device=device
        )

        # Initial conditions for the ODE solver, registered as buffers
        self.register_buffer("initial_r", torch.ones(N_osc, device=device) * 0.1)
        self.register_buffer("initial_phi", torch.zeros(N_osc, device=device))

        # Stability clamps, as in original loop for final output
        self.r_min = 0.01
        self.r_max = 2.0

    def forward(self, input_features):
        # input_features: (B, N_osc) from ECGToOscillatorMLP.pre_osc
        B = input_features.shape[0]

        # Convert input_features to (B, N_osc, 1) for consistency in ODEFuc
        self.ode_func.input_f = input_features.unsqueeze(-1)

        # Prepare initial state y0 = [r, phi] for all batches
        initial_r_batch = self.initial_r.unsqueeze(0).repeat(B, 1) # (B, N_osc)
        initial_phi_batch = self.initial_phi.unsqueeze(0).repeat(B, 1) # (B, N_osc)
        y0 = torch.cat([initial_r_batch, initial_phi_batch], dim=-1) # (B, N_osc * 2)

        # Generate time steps
        t_eval = torch.arange(0, self.T, self.dt, device=input_features.device, dtype=torch.float32)

        # Solve the ODE using odeint (not odeint_adjoint to allow gradients to flow)
        sol = odeint(
            self.ode_func,
            y0,
            t_eval,
            method="rk4" # Use the same method as TorchRevHopfNetwork
        ) # sol shape: (T_steps, B, N_osc * 2)

        # Extract final r and phi (last time step)
        r_final = sol[-1, :, :self.N_osc] # (B, N_osc)
        phi_final = sol[-1, :, self.N_osc:] # (B, N_osc)

        # Apply final amplitude clamp as in original loop
        r_final = torch.clamp(r_final, self.r_min, self.r_max)

        return torch.cat([
            r_final * torch.cos(phi_final),
            #r_final * torch.sin(phi_final)
        ], dim=-1)

# %%
class ECGToOscillatorMLP(nn.Module):
    """ECG → MLP → OscillatorLayer → MLP → Brain drive [N]"""
    def __init__(self, ecg_dim=50, N_VNS=16, hidden_dim=64, output_dim=16, device="cuda"):
        super().__init__()
        self.pre_osc = nn.Sequential(
            nn.Linear(ecg_dim, hidden_dim), nn.SiLU(),
            nn.Linear(hidden_dim, hidden_dim), nn.SiLU(),
            nn.Linear(hidden_dim, N_VNS)
        )
        self.osc_layer = OscillatorLayer(N_osc=N_VNS, device=device, coupling_sparsity=0.3, seed=42)
        self.post_osc = nn.Sequential(
            nn.Linear(N_VNS * 1, hidden_dim),
            nn.SiLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.SiLU(),
            nn.Linear(hidden_dim, output_dim)
        )

    def forward(self, ecg_features):  # [batch, ecg_dim] or [ecg_dim]
        if ecg_features.dim() == 1:
            ecg_features = ecg_features.unsqueeze(0)  # (1, ecg_dim)

        ecg_features = (
            ecg_features - ecg_features.mean(dim=-1, keepdim=True)
        ) / (ecg_features.std(dim=-1, keepdim=True) + 1e-6)

        pre = self.pre_osc(ecg_features)
        osc_hidden = self.osc_layer(pre)
        combined = torch.cat([osc_hidden], dim=-1)
        brain_drive = self.post_osc(combined)

        if brain_drive.shape[0] == 1:
            return brain_drive.squeeze(0)  # (output_dim,)
        return brain_drive
    
class FeedbackMLP(nn.Module):
    def __init__(self, input_dim=16, hidden_dim=64, output_dim=2):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim), nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim), nn.ReLU(),
            nn.Linear(hidden_dim, output_dim)
        )

    def forward(self, mlp_output):
        return self.net(mlp_output)

# %%
class ODEFuc(nn.Module):
    def __init__(self, mu, eta_theta, eta_omega, eta_alpha,
                 D_function, N, Sc,
                 brain_drive_full=None,
                 fs=100):

        super().__init__()
        self.mu = mu
        self.eta_theta = eta_theta
        self.eta_omega = eta_omega
        self.eta_alpha = eta_alpha
        self.D_function = D_function
        self.N = N
        self.fs = fs

        self.register_buffer(
            'Sc',
            torch.tensor(Sc, dtype=torch.float32)
        )

        # brain_drive_full is stored as a plain attribute (NOT a buffer) so that
        # when using standard odeint, the full autograd graph is preserved and
        # gradients flow back through it to ecg_to_osc_mlp.
        self.brain_drive_full = brain_drive_full

    def forward(self, t, state):

        N = self.N

        r = state[:N]
        phi = state[N:2*N]
        theta = state[2*N:2*N + N**2].view(N, N)
        omega = state[2*N + N**2:3*N + N**2]
        alpha = state[3*N + N**2:4*N + N**2]

        omega_safe = torch.clamp(omega, 2 * np.pi * 0.5, 2 * np.pi * 20)
        r = torch.clamp(r, 1e-1, 2.0)
        alpha = torch.clamp(alpha, -1.0, 1.0)
        r_safe = torch.clamp(torch.where(r < 1e-6, torch.tensor(1e-6, device=r.device, dtype=r.dtype), r), 1e-5, 10.0)  # Higher min for stability
        r = r_safe

        # --- Correct Phase Difference for Power Coupling ---
        #phase_diff = (
        #    omega_ratio * phi[None, :]  ## Use Phi/omega- Phi/omega +theta/(omega1*omega2)
        #    - phi[:, None]
        #    + theta
        #)
        ## reviseed phase dofference..
        # Phase differences matrix
        phase_diff = torch.clamp(
            phi[None, :] / omega_safe[None, :] -
            phi[:, None] / omega_safe[:, None] +
            theta / (omega_safe[:, None] * omega_safe[None, :]), -1e2, 1e2)  # Added clamp to prevent extreme phases


        # ----- Target forcing -----
        D = torch.tensor(
            self.D_function(t.item()),
            device=state.device,
            dtype=state.dtype
        )

        P = torch.sum(alpha * r * torch.cos(phi))
        e = D - P

        # ----- Precomputed brain drive indexing -----
        if self.brain_drive_full is not None:
            t_idx = min(
                round(t.item() * self.fs),
                self.brain_drive_full.shape[0] - 1
            )
            ecg_input = self.brain_drive_full[t_idx]
        else:
            ecg_input = torch.zeros(N, device=state.device)

        # ----- Dynamics -----
        # Safe Log-Domain Power
        #log_r = torch.log(r_safe)
        #r_power = torch.exp(omega_ratio * log_r[None, :])

        coupling_r = torch.sum(torch.abs(self.Sc) * r[None, :] * torch.cos(phase_diff), dim=1)

        drdt = (self.mu - r**2) * r \
               + coupling_r \
               + e * torch.cos(phi) \
               + ecg_input


        #Radius dynamics
        #drdt = (self.mu - r**2) * r + np.sum(
        #    A * r[None, :]**omega_ratio *
        #    np.cos(self.omega[:, None] * phase_diff),
        #    axis=1
        #)

        coupling_phi = torch.sum(torch.abs(self.Sc) * (r[None, :] / r_safe[:, None]) * torch.sin(phase_diff), dim=1)
        dphidt = omega + coupling_phi - (e / r_safe) * torch.sin(phi)

         # Adaptive dynamics (these are "frozen" by setting etas to 0 in Stage 2)
        dthetadt = self.eta_theta * torch.sin(phase_diff) * torch.abs(self.Sc)
        domegadt = -self.eta_omega * e * torch.sin(phi)
        dalphadt = self.eta_alpha * e * r * torch.cos(phi)

        # Clamp gradients to prevent explosions

        ## Put a clamp  on drdt, domegadt to restrict the bound..
        return torch.cat([
            drdt.flatten(),
            dphidt.flatten(),
            dthetadt.flatten(),
            domegadt.flatten(),
            dalphadt.flatten()
        ])


class TorchRevHopfNetwork:
    def __init__(self, mu, eta_omega, eta_alpha, eta_theta,
                 D_function, N, Sc,
                 brain_drive_full=None,
                 fs=100,
                 device="cuda"):

        self.device = torch.device(device)
        self.N = N

        self.ode_func = ODEFuc(
            mu=mu,
            eta_theta=eta_theta,
            eta_omega=eta_omega,
            eta_alpha=eta_alpha,
            D_function=D_function,
            N=N,
            Sc=Sc,
            brain_drive_full=brain_drive_full,
            fs=fs
        ).to(self.device)

    def solve(self, r0, phi0, theta0, omega0, alpha0, t_eval, use_adjoint=True):
        # use_adjoint=True  → odeint_adjoint (memory-efficient, for no-grad stages)
        # use_adjoint=False → odeint (standard autograd graph, required when
        #                    brain_drive_full must carry gradients back to ecg_to_osc_mlp)

        y0 = torch.tensor(
            np.concatenate([r0, phi0, theta0.flatten(), omega0, alpha0]),
            device=self.device,
            dtype=torch.float32
        )

        t_eval_tensor = torch.tensor(
            t_eval,
            device=self.device,
            dtype=torch.float32
        )

        if use_adjoint:
            sol = odeint_adjoint(
                self.ode_func,
                y0,
                t_eval_tensor,
                method="rk4"
            )
        else:
            # Standard odeint builds a full autograd graph so gradients flow
            # back through brain_drive_full to ecg_to_osc_mlp parameters.
            sol = odeint(
                self.ode_func,
                y0,
                t_eval_tensor,
                method="rk4"
            )

        N = self.N

        r = sol[:, :N]
        phi = sol[:, N:2*N]
        theta = sol[:, 2*N:2*N + N**2].view(-1, N, N)
        omega = sol[:, 2*N + N**2:3*N + N**2]
        alpha = sol[:, 3*N + N**2:4*N + N**2]

        rcos_phi = torch.sum(r * torch.cos(phi), dim=1)

        return r, phi, theta, omega, alpha, rcos_phi

# %%
def train_heart_model(ecg_target_signal, t_duration_train, fs, device):
    heart_model = HeartModel().to(device)
    optimizer = optim.Adam(heart_model.parameters(), lr=1e-3)
    criterion = nn.MSELoss()

    sim_osc_input = torch.tensor(simulate_coupled_oscillators(T=t_duration_train, dt=1/fs), dtype=torch.float32).to(device)
    ecg_target = torch.tensor(ecg_target_signal, dtype=torch.float32).to(device).unsqueeze(1)

    num_epochs = 25000
    for epoch in range(num_epochs):
        predicted_ecg = heart_model(sim_osc_input)
        loss = criterion(predicted_ecg, ecg_target)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if (epoch + 1) % 250 == 0:
            print(f"Heart Model Epoch {epoch+1}/{num_epochs}, Loss: {loss.item():.6f}")

    print("--- Heart Model Pre-training Finished ---")
    return heart_model

def pre_train_brain_model(eeg_train_data, Sw_all, target_idx, non_zero_indices_per_row, t, D_function, device):
    print("\n--- Starting Brain Dynamics Pre-training (Stage 1) ---")
    connected_indices = np.unique(np.append(non_zero_indices_per_row[target_idx], target_idx))
    N_reduced_regions = len(connected_indices)
    osc_per_region = 5
    N = N_reduced_regions * osc_per_region
    print(f"Reduced network has {N_reduced_regions} regions. Total oscillators: {N}")

    Sc_reduced_regional = Sw_all[np.ix_(connected_indices, connected_indices)]
    Sc_reduced_osc = expand_structural_connectivity(Sc_reduced_regional, osc_per_region, seed=42)

    omega_full = get_random_frequencies(Sw_all.shape[0], osc_per_region, low=1, high=20, seed=42)
    alpha_full = np.random.uniform(0.1, 0.7, Sw_all.shape[0] * osc_per_region)
    omega0 = np.concatenate([omega_full[i*osc_per_region:(i+1)*osc_per_region] for i in connected_indices])
    alpha0 = np.clip(np.concatenate([alpha_full[i*osc_per_region:(i+1)*osc_per_region] for i in connected_indices]), 0.05, 0.5)
    r0 = 0.1 * np.ones(N)
    phi0 = np.zeros(N)

    theta_random = np.pi * (2 * np.random.rand(N, N) - 1)
    theta0 = theta_random - theta_random.T

    model = TorchRevHopfNetwork(
        mu=1.0, eta_omega=0.05, eta_alpha=0.005, eta_theta=0.05,
        D_function=D_function, N=N, Sc=Sc_reduced_osc,
        mlp_model=None, hidden_repr=None, device=device
    )

    criterion = nn.MSELoss()
    D_true = torch.tensor(D_function(t), device=device, dtype=torch.float32)

    num_epochs = 1000
    losses = []
    print("Solving ODE iteratively to adapt brain dynamics...")
    for epoch in range(num_epochs):
        with torch.no_grad():
            r, phi, theta, omega, alpha = model.solve(r0, phi0, theta0, omega0, alpha0, t)
            P_out = torch.sum(alpha * r * torch.cos(phi), axis=1)
            loss = criterion(P_out, D_true)
            losses.append(loss.item())

            if (epoch + 1) % 10 == 0:
                print(f"Brain Pre-training Epoch {epoch+1}/{num_epochs}, Loss: {loss.item():.6f}")

            theta0 = theta[-1].detach().cpu().numpy()
            omega0 = omega[-1].detach().cpu().numpy()
            alpha0 = alpha[-1].detach().cpu().numpy()

            del r, phi, theta, omega, alpha, P_out, loss
            if device == 'cuda':
                torch.cuda.empty_cache()

    final_params = {'r': r0, 'phi': phi0, 'theta': theta0, 'omega': omega0, 'alpha': alpha0}
    print("--- Brain Dynamics Pre-training Finished ---")
    return final_params, Sc_reduced_osc, N, losses

def train_mlp_on_frozen_brain(trained_heart_model, initial_brain_params, Sc_reduced_osc, N, D_function, t, t_duration_train, fs, device):
    print("\n--- Starting MLP Training with Frozen Brain (Stage 2) ---")
    r0, phi0, theta0, omega0, alpha0 = (
        initial_brain_params['r'], initial_brain_params['phi'],
        initial_brain_params['theta'], initial_brain_params['omega'],
        initial_brain_params['alpha']
    )

    trained_heart_model.eval()
    mlp_model = ECGToOscillatorMLP(output_dim=N).to(device)
    optimizer = torch.optim.Adam(mlp_model.parameters(), lr=1e-2)
    criterion = nn.MSELoss()

    simulated_ecg_input = torch.tensor(simulate_coupled_oscillators(T=t_duration_train, dt=1/fs),
                                           dtype=torch.float32).to(device)

    num_epochs = 1000
    losses = []
    for epoch in range(num_epochs):
        mlp_model.train()
        with torch.no_grad():
            hidden_repr = trained_heart_model.get_features(simulated_ecg_input)

        model = TorchRevHopfNetwork(
            mu=1.0, eta_omega=0.0, eta_alpha=0.0, eta_theta=0.0,
            D_function=D_function, N=N, Sc=Sc_reduced_osc,
            mlp_model=mlp_model, hidden_repr=hidden_repr, device=device
        )

        r, phi, theta, omega, alpha = model.solve(r0, phi0, theta0, omega0, alpha0, t)

        P_out = torch.sum(alpha * r * torch.cos(phi), axis=1)
        D_true = torch.tensor(D_function(t), device=device, dtype=torch.float32)
        loss = criterion(P_out, D_true)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        losses.append(loss.item())
        if (epoch + 1) % 50 == 0:
            print(f"MLP Training Epoch {epoch+1}/{num_epochs}, Loss: {loss.item():.6f}")

        del model, r, phi, theta, omega, alpha, hidden_repr
        if device == 'cuda':
            torch.cuda.empty_cache()

    print("--- Stage 2 Finished ---")
    return mlp_model, losses

def train_feedback_loop(trained_heart_model, trained_mlp_model, ecg_target_signal, T, dt, device, num_epochs=70000, loop_iterations=1):
    print("--- Starting Feedback Loop Training ---")

    trained_heart_model.apply(reset_weights)
    trained_heart_model.train()
    feedback_mlp = FeedbackMLP(input_dim=trained_mlp_model.net[-1].out_features).to(device)
    optimizer = optim.Adam(list(trained_heart_model.parameters()) + list(feedback_mlp.parameters()), lr=1e-3)
    criterion = nn.MSELoss()

    num_samples = int(np.round(T / dt))
    time_axis = np.linspace(0, T, num_samples, endpoint=False)
    ecg_interp = interp1d(np.linspace(0, T, len(ecg_target_signal), endpoint=False), ecg_target_signal,
                          kind='linear', bounds_error=False, fill_value="extrapolate")
    ecg_target_resampled = torch.tensor(ecg_interp(time_axis), dtype=torch.float32, device=device).unsqueeze(1)

    for epoch in range(num_epochs):
        sim_osc = simulate_coupled_oscillators(T=T, dt=dt)
        sim_osc_tensor = torch.tensor(sim_osc, dtype=torch.float32, device=device)

        for _ in range(loop_iterations):
            hidden_repr = trained_heart_model.get_features(sim_osc_tensor)
            mlp_output = trained_mlp_model(hidden_repr)
            feedback_output = feedback_mlp(mlp_output)
            feedback_np = feedback_output.detach().cpu().numpy()

            sim_osc = simulate_coupled_oscillators(T=T, dt=dt, modulation=feedback_np)
            sim_osc_tensor = torch.tensor(sim_osc, dtype=torch.float32, device=device)

        predicted_ecg = trained_heart_model(sim_osc_tensor)
        loss = criterion(predicted_ecg, ecg_target_resampled)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (epoch + 1) % 50 == 0:
            print(f"Feedback Loop Epoch {epoch+1}/{num_epochs}, Loss: {loss.item():.6f}")

    print("--- Feedback Loop Training Finished ---")
    return trained_heart_model, feedback_mlp

# %%
if __name__ == '__main__':
    device = "cuda" if torch.cuda.is_available() else "cpu"
    print(f"--- Using device: {device} ---")

    trained_heart_model = train_heart_model(ecg_train, train_duration, fs, device)

    final_brain_params, Sc_reduced_osc, N, brain_losses = pre_train_brain_model(
        eeg_train, Sw_all, target_idx, non_zero_indices_per_row, t_train, D_function, device
    )

    # Step 3: Freeze brain and train MLP on training data
    trained_mlp_model, mlp_losses = train_mlp_on_frozen_brain(
        trained_heart_model, final_brain_params, Sc_reduced_osc, N, D_function, t_train, train_duration, fs, device
    )

    # Step 4: Retrain heart model with feedback on training data
    trained_heart_model, trained_feedback_mlp = train_feedback_loop(
        trained_heart_model, trained_mlp_model, ecg_train, T=train_duration, dt=1/fs, device=device, num_epochs=70000, loop_iterations=1
    )

    # ---- Final prediction on FULL dataset (train + test) ----
    print("\n--- Generating final predictions for train and test sets ---")
    trained_heart_model.eval()
    trained_mlp_model.eval()
    trained_feedback_mlp.eval()

    with torch.no_grad():
        r0, phi0, theta0, omega0, alpha0 = (
            final_brain_params['r'], final_brain_params['phi'],
            final_brain_params['theta'], final_brain_params['omega'],
            final_brain_params['alpha']
        )

        # Simulate heart-brain interaction over the full duration
        sim_osc_final = simulate_coupled_oscillators(T=total_duration, dt=1/fs)
        sim_osc_tensor = torch.tensor(sim_osc_final, dtype=torch.float32, device=device)
        hidden_repr_final = trained_heart_model.get_features(sim_osc_tensor)
        mlp_output_final = trained_mlp_model(hidden_repr_final)

        feedback_output = trained_feedback_mlp(mlp_output_final)
        feedback_np = feedback_output.detach().cpu().numpy()
        sim_osc_final = simulate_coupled_oscillators(T=total_duration, dt=1/fs, modulation=feedback_np)
        sim_osc_tensor = torch.tensor(sim_osc_final, dtype=torch.float32, device=device)
        hidden_repr_final = trained_heart_model.get_features(sim_osc_tensor)

        # Predict ECG for the full duration
        predicted_ecg_final = trained_heart_model(sim_osc_tensor).detach().cpu().numpy().flatten()

        # Predict EEG for the full duration
        # Create a new D_function for the full duration for the final solve
        D_function_full = interp1d(t_full, target_signal_full, kind='linear', bounds_error=False, fill_value=0.0)
        model_final = TorchRevHopfNetwork(
            mu=1.0, eta_omega=0.0, eta_alpha=0.0, eta_theta=0.0,
            D_function=D_function_full, N=N, Sc=Sc_reduced_osc,
            mlp_model=trained_mlp_model, hidden_repr=hidden_repr_final, device=device
        )

        r, phi, theta, omega, alpha = model_final.solve(r0, phi0, theta0, omega0, alpha0, t_full)
        P_out_final = torch.sum(alpha * r * torch.cos(phi), axis=1).detach().cpu().numpy()

    # Split predictions into train and test sets for plotting
    pred_ecg_train = predicted_ecg_final[:train_samples]
    pred_ecg_test = predicted_ecg_final[train_samples:]

    pred_eeg_train = P_out_final[:train_samples]
    pred_eeg_test = P_out_final[train_samples:]

    # --- Plotting ---
    plt.figure(figsize=(16, 12))

    # Plot EEG results
    ax1 = plt.subplot(2, 1, 1)
    ax1.plot(t_train, target_signal_train, label='Actual EEG (Train)', color='blue', alpha=0.8)
    ax1.plot(t_train, pred_eeg_train, label='Predicted EEG (Train)', color='cyan', linestyle='--')
    ax1.plot(t_test, eeg_test[target_idx], label='Actual EEG (Test)', color='green', alpha=0.8)
    ax1.plot(t_test, pred_eeg_test, label='Predicted EEG (Test)', color='lime', linestyle='--')
    ax1.axvline(x=train_duration, color='k', linestyle=':', linewidth=2, label='Train/Test Split')
    ax1.set_title(f'EEG Prediction (Region {target_idx})')
    ax1.set_xlabel('Time (s)')
    ax1.set_ylabel('Normalized Amplitude')
    ax1.legend()
    ax1.grid(True)

    # Plot ECG results
    ax2 = plt.subplot(2, 1, 2)
    ax2.plot(t_train, ecg_train, label='Actual ECG (Train)', color='red', alpha=0.8)
    ax2.plot(t_train, pred_ecg_train, label='Predicted ECG (Train)', color='orange', linestyle='--')
    ax2.plot(t_test, ecg_test, label='Actual ECG (Test)', color='purple', alpha=0.8)
    ax2.plot(t_test, pred_ecg_test, label='Predicted ECG (Test)', color='magenta', linestyle='--')
    ax2.axvline(x=train_duration, color='k', linestyle=':', linewidth=2, label='Train/Test Split')
    ax2.set_title('ECG Prediction')
    ax2.set_xlabel('Time (s)')
    ax2.set_ylabel('Normalized Amplitude')
    ax2.legend()
    ax2.grid(True)

    plt.tight_layout()
    plt.show()

    # Save final predictions if needed
    np.save("P_out_final_1.npy", P_out_final)
    np.save("predicted_ecg_final_1.npy", predicted_ecg_final)
# Out:
# --- Using device: cuda ---
# --- Starting Heart Model Pre-training ---
# Heart Model Epoch 250/25000, Loss: 0.009519
# Heart Model Epoch 500/25000, Loss: 0.009494
# Heart Model Epoch 750/25000, Loss: 0.009432
# Heart Model Epoch 1000/25000, Loss: 0.009097
# Heart Model Epoch 1250/25000, Loss: 0.008358
# Heart Model Epoch 1500/25000, Loss: 0.007939
# Heart Model Epoch 1750/25000, Loss: 0.007546
# Heart Model Epoch 2000/25000, Loss: 0.007161
# Heart Model Epoch 2250/25000, Loss: 0.006898
# Heart Model Epoch 2500/25000, Loss: 0.006650
# Heart Model Epoch 2750/25000, Loss: 0.006454
# Heart Model Epoch 3000/25000, Loss: 0.006175
# Heart Model Epoch 3250/25000, Loss: 0.005973
# Heart Model Epoch 3500/25000, Loss: 0.005774
# Heart Model Epoch 3750/25000, Loss: 0.005600
# Heart Model Epoch 4000/25000, Loss: 0.005451
# Heart Model Epoch 4250/25000, Loss: 0.005374
# Heart Model Epoch 4500/25000, Loss: 0.005271
# Heart Model Epoch 4750/25000, Loss: 0.005218
# Heart Model Epoch 5000/25000, Loss: 0.005151
# Heart Model Epoch 5250/25000, Loss: 0.005111
# Heart Model Epoch 5500/25000, Loss: 0.005162
# Heart Model Epoch 5750/25000, Loss: 0.005026
# Heart Model Epoch 6000/25000, Loss: 0.004998
# Heart Model Epoch 6250/25000, Loss: 0.004957
# Heart Model Epoch 6500/25000, Loss: 0.004933
# Heart Model Epoch 6750/25000, Loss: 0.004936
# Heart Model Epoch 7000/25000, Loss: 0.004877
# Heart Model Epoch 7250/25000, Loss: 0.004857
# Heart Model Epoch 7500/25000, Loss: 0.004824
# Heart Model Epoch 7750/25000, Loss: 0.004805
# Heart Model Epoch 8000/25000, Loss: 0.004816
# Heart Model Epoch 8250/25000, Loss: 0.004756
# Heart Model Epoch 8500/25000, Loss: 0.004740
# Heart Model Epoch 8750/25000, Loss: 0.004711
# Heart Model Epoch 9000/25000, Loss: 0.004696
# Heart Model Epoch 9250/25000, Loss: 0.005171
# Heart Model Epoch 9500/25000, Loss: 0.004655
# Heart Model Epoch 9750/25000, Loss: 0.004712
# Heart Model Epoch 10000/25000, Loss: 0.004614
# Heart Model Epoch 10250/25000, Loss: 0.004601
# Heart Model Epoch 10500/25000, Loss: 0.004653
# Heart Model Epoch 10750/25000, Loss: 0.004562
# Heart Model Epoch 11000/25000, Loss: 0.004554
# Heart Model Epoch 11250/25000, Loss: 0.004527
# Heart Model Epoch 11500/25000, Loss: 0.004518
# Heart Model Epoch 11750/25000, Loss: 0.006855
# Heart Model Epoch 12000/25000, Loss: 0.004487
# Heart Model Epoch 12250/25000, Loss: 0.004486
# Heart Model Epoch 12500/25000, Loss: 0.004457
# Heart Model Epoch 12750/25000, Loss: 0.004452
# Heart Model Epoch 13000/25000, Loss: 0.004428
# Heart Model Epoch 13250/25000, Loss: 0.004422
# Heart Model Epoch 13500/25000, Loss: 0.004431
# Heart Model Epoch 13750/25000, Loss: 0.004396
# Heart Model Epoch 14000/25000, Loss: 0.004394
# Heart Model Epoch 14250/25000, Loss: 0.004370
# Heart Model Epoch 14500/25000, Loss: 0.004365
# Heart Model Epoch 14750/25000, Loss: 0.004997
# Heart Model Epoch 15000/25000, Loss: 0.004342
# Heart Model Epoch 15250/25000, Loss: 0.004361
# Heart Model Epoch 15500/25000, Loss: 0.004319
# Heart Model Epoch 15750/25000, Loss: 0.004319
# Heart Model Epoch 16000/25000, Loss: 0.004298
# Heart Model Epoch 16250/25000, Loss: 0.004294
# Heart Model Epoch 16500/25000, Loss: 0.004305
# Heart Model Epoch 16750/25000, Loss: 0.004274
# Heart Model Epoch 17000/25000, Loss: 0.004272
# Heart Model Epoch 17250/25000, Loss: 0.004255
# Heart Model Epoch 17500/25000, Loss: 0.004252
# Heart Model Epoch 17750/25000, Loss: 0.004252
# Heart Model Epoch 18000/25000, Loss: 0.004234
# Heart Model Epoch 18250/25000, Loss: 0.004231
# Heart Model Epoch 18500/25000, Loss: 0.004238
# Heart Model Epoch 18750/25000, Loss: 0.004216
# Heart Model Epoch 19000/25000, Loss: 0.004215
# Heart Model Epoch 19250/25000, Loss: 0.005558
# Heart Model Epoch 19500/25000, Loss: 0.004198
# Heart Model Epoch 19750/25000, Loss: 0.004200
# Heart Model Epoch 20000/25000, Loss: 0.004183
# Heart Model Epoch 20250/25000, Loss: 0.004183
# Heart Model Epoch 20500/25000, Loss: 0.004209
# Heart Model Epoch 20750/25000, Loss: 0.004168
# Heart Model Epoch 21000/25000, Loss: 0.004168
# Heart Model Epoch 21250/25000, Loss: 0.006184
# Heart Model Epoch 21500/25000, Loss: 0.004153
# Heart Model Epoch 21750/25000, Loss: 0.004154
# Heart Model Epoch 22000/25000, Loss: 0.004139
# Heart Model Epoch 22250/25000, Loss: 0.004137
# Heart Model Epoch 22500/25000, Loss: 0.004142
# Heart Model Epoch 22750/25000, Loss: 0.004124
# Heart Model Epoch 23000/25000, Loss: 0.004123
# Heart Model Epoch 23250/25000, Loss: 0.004137
# Heart Model Epoch 23500/25000, Loss: 0.004108
# Heart Model Epoch 23750/25000, Loss: 0.004107
# Heart Model Epoch 24000/25000, Loss: 0.004140
# Heart Model Epoch 24250/25000, Loss: 0.004092
# Heart Model Epoch 24500/25000, Loss: 0.004093
# Heart Model Epoch 24750/25000, Loss: 0.004078
# Heart Model Epoch 25000/25000, Loss: 0.004076
# --- Heart Model Pre-training Finished ---
#
# --- Starting Brain Dynamics Pre-training (Stage 1) ---
# Reduced network has 62 regions. Total oscillators: 310
# Solving ODE iteratively to adapt brain dynamics...
# Brain Pre-training Epoch 10/1000, Loss: 8.320109
# Brain Pre-training Epoch 20/1000, Loss: 6.337668
# Brain Pre-training Epoch 30/1000, Loss: 4.794181
# Brain Pre-training Epoch 40/1000, Loss: 3.510614
# Brain Pre-training Epoch 50/1000, Loss: 2.792153
# Brain Pre-training Epoch 60/1000, Loss: 2.368035
# Brain Pre-training Epoch 70/1000, Loss: 2.101262
# Brain Pre-training Epoch 80/1000, Loss: 1.913822
# Brain Pre-training Epoch 90/1000, Loss: 1.770206
# Brain Pre-training Epoch 100/1000, Loss: 1.653041
# Brain Pre-training Epoch 110/1000, Loss: 1.558882
# Brain Pre-training Epoch 120/1000, Loss: 1.485025
# Brain Pre-training Epoch 130/1000, Loss: 1.423183
# Brain Pre-training Epoch 140/1000, Loss: 1.370904
# Brain Pre-training Epoch 150/1000, Loss: 1.322282
# Brain Pre-training Epoch 160/1000, Loss: 1.269943
# Brain Pre-training Epoch 170/1000, Loss: 1.224394
# Brain Pre-training Epoch 180/1000, Loss: 1.177713
# Brain Pre-training Epoch 190/1000, Loss: 1.126137
# Brain Pre-training Epoch 200/1000, Loss: 1.067814
# Brain Pre-training Epoch 210/1000, Loss: 1.004717
# Brain Pre-training Epoch 220/1000, Loss: 0.943218
# Brain Pre-training Epoch 230/1000, Loss: 0.880607
# Brain Pre-training Epoch 240/1000, Loss: 0.816605
# Brain Pre-training Epoch 250/1000, Loss: 0.754446
# Brain Pre-training Epoch 260/1000, Loss: 0.697422
# Brain Pre-training Epoch 270/1000, Loss: 0.647095
# Brain Pre-training Epoch 280/1000, Loss: 0.605121
# Brain Pre-training Epoch 290/1000, Loss: 0.572955
# Brain Pre-training Epoch 300/1000, Loss: 0.548367
# Brain Pre-training Epoch 310/1000, Loss: 0.527750
# Brain Pre-training Epoch 320/1000, Loss: 0.509055
# Brain Pre-training Epoch 330/1000, Loss: 0.492065
# Brain Pre-training Epoch 340/1000, Loss: 0.477049
# Brain Pre-training Epoch 350/1000, Loss: 0.464044
# Brain Pre-training Epoch 360/1000, Loss: 0.452329
# Brain Pre-training Epoch 370/1000, Loss: 0.441937
# Brain Pre-training Epoch 380/1000, Loss: 0.432627
# Brain Pre-training Epoch 390/1000, Loss: 0.424068
# Brain Pre-training Epoch 400/1000, Loss: 0.416229
# Brain Pre-training Epoch 410/1000, Loss: 0.408840
# Brain Pre-training Epoch 420/1000, Loss: 0.401873
# Brain Pre-training Epoch 430/1000, Loss: 0.395232
# Brain Pre-training Epoch 440/1000, Loss: 0.388632
# Brain Pre-training Epoch 450/1000, Loss: 0.382012
# Brain Pre-training Epoch 460/1000, Loss: 0.375611
# Brain Pre-training Epoch 470/1000, Loss: 0.369759
# Brain Pre-training Epoch 480/1000, Loss: 0.364061
# Brain Pre-training Epoch 490/1000, Loss: 0.358652
# Brain Pre-training Epoch 500/1000, Loss: 0.353688
# Brain Pre-training Epoch 510/1000, Loss: 0.349349
# Brain Pre-training Epoch 520/1000, Loss: 0.345583
# Brain Pre-training Epoch 530/1000, Loss: 0.342316
# Brain Pre-training Epoch 540/1000, Loss: 0.339680
# Brain Pre-training Epoch 550/1000, Loss: 0.336161
# Brain Pre-training Epoch 560/1000, Loss: 0.329908
# Brain Pre-training Epoch 570/1000, Loss: 0.323981
# Brain Pre-training Epoch 580/1000, Loss: 0.319032
# Brain Pre-training Epoch 590/1000, Loss: 0.314628
# Brain Pre-training Epoch 600/1000, Loss: 0.309692
# Brain Pre-training Epoch 610/1000, Loss: 0.304938
# Brain Pre-training Epoch 620/1000, Loss: 0.300748
# Brain Pre-training Epoch 630/1000, Loss: 0.296071
# Brain Pre-training Epoch 640/1000, Loss: 0.290844
# Brain Pre-training Epoch 650/1000, Loss: 0.286522
# Brain Pre-training Epoch 660/1000, Loss: 0.283195
# Brain Pre-training Epoch 670/1000, Loss: 0.280085
# Brain Pre-training Epoch 680/1000, Loss: 0.276881
# Brain Pre-training Epoch 690/1000, Loss: 0.274318
# Brain Pre-training Epoch 700/1000, Loss: 0.272361
# Brain Pre-training Epoch 710/1000, Loss: 0.273971
# Brain Pre-training Epoch 720/1000, Loss: 0.271366
# Brain Pre-training Epoch 730/1000, Loss: 0.270875
# Brain Pre-training Epoch 740/1000, Loss: 0.270845
# Brain Pre-training Epoch 750/1000, Loss: 0.270948
# Brain Pre-training Epoch 760/1000, Loss: 0.268550
# Brain Pre-training Epoch 770/1000, Loss: 0.267298
# Brain Pre-training Epoch 780/1000, Loss: 0.265745
# Brain Pre-training Epoch 790/1000, Loss: 0.262118
# Brain Pre-training Epoch 800/1000, Loss: 0.258688
# Brain Pre-training Epoch 810/1000, Loss: 0.254125
# Brain Pre-training Epoch 820/1000, Loss: 0.250333
# Brain Pre-training Epoch 830/1000, Loss: 0.248564
# Brain Pre-training Epoch 840/1000, Loss: 0.247332
# Brain Pre-training Epoch 850/1000, Loss: 0.245955
# Brain Pre-training Epoch 860/1000, Loss: 0.245044
# Brain Pre-training Epoch 870/1000, Loss: 0.244503
# Brain Pre-training Epoch 880/1000, Loss: 0.244011
# Brain Pre-training Epoch 890/1000, Loss: 0.243323
# Brain Pre-training Epoch 900/1000, Loss: 0.242440
# Brain Pre-training Epoch 910/1000, Loss: 0.241493
# Brain Pre-training Epoch 920/1000, Loss: 0.240474
# Brain Pre-training Epoch 930/1000, Loss: 0.239376
# Brain Pre-training Epoch 940/1000, Loss: 0.238309
# Brain Pre-training Epoch 950/1000, Loss: 0.237278
# Brain Pre-training Epoch 960/1000, Loss: 0.235535
# Brain Pre-training Epoch 970/1000, Loss: 0.231349
# Brain Pre-training Epoch 980/1000, Loss: 0.228827
# Brain Pre-training Epoch 990/1000, Loss: 0.227913
# Brain Pre-training Epoch 1000/1000, Loss: 0.227325
# --- Brain Dynamics Pre-training Finished ---
#
# --- Starting MLP Training with Frozen Brain (Stage 2) ---
# MLP Training Epoch 50/1000, Loss: 0.219851
# MLP Training Epoch 100/1000, Loss: 0.208837
# MLP Training Epoch 150/1000, Loss: 0.206650
# MLP Training Epoch 200/1000, Loss: 0.204932
# MLP Training Epoch 250/1000, Loss: 0.203324
# MLP Training Epoch 300/1000, Loss: 0.202542
# MLP Training Epoch 350/1000, Loss: 0.201933
# MLP Training Epoch 400/1000, Loss: 0.201710
# MLP Training Epoch 450/1000, Loss: 0.201507
# MLP Training Epoch 500/1000, Loss: 0.201319
# MLP Training Epoch 550/1000, Loss: 0.201151
# MLP Training Epoch 600/1000, Loss: 0.201000
# MLP Training Epoch 650/1000, Loss: 0.200847
# MLP Training Epoch 700/1000, Loss: 0.200943
# MLP Training Epoch 750/1000, Loss: 0.200737
# MLP Training Epoch 800/1000, Loss: 0.200623
# MLP Training Epoch 850/1000, Loss: 0.200475
# MLP Training Epoch 900/1000, Loss: 0.200367
# MLP Training Epoch 950/1000, Loss: 0.200226
# MLP Training Epoch 1000/1000, Loss: 0.200087
# --- Stage 2 Finished ---
# --- Starting Feedback Loop Training ---
# Feedback Loop Epoch 50/70000, Loss: 0.010069
# Feedback Loop Epoch 100/70000, Loss: 0.009548
# Feedback Loop Epoch 150/70000, Loss: 0.009510
# Feedback Loop Epoch 200/70000, Loss: 0.009506
# Feedback Loop Epoch 250/70000, Loss: 0.009502
# Feedback Loop Epoch 300/70000, Loss: 0.009498
# Feedback Loop Epoch 350/70000, Loss: 0.009493
# Feedback Loop Epoch 400/70000, Loss: 0.009487
# Feedback Loop Epoch 450/70000, Loss: 0.009481
# Feedback Loop Epoch 500/70000, Loss: 0.009473
# Feedback Loop Epoch 550/70000, Loss: 0.009464
# Feedback Loop Epoch 600/70000, Loss: 0.009451
# Feedback Loop Epoch 650/70000, Loss: 0.009434
# Feedback Loop Epoch 700/70000, Loss: 0.009409
# Feedback Loop Epoch 750/70000, Loss: 0.009371
# Feedback Loop Epoch 800/70000, Loss: 0.009314
# Feedback Loop Epoch 850/70000, Loss: 0.009228
# Feedback Loop Epoch 900/70000, Loss: 0.009104
# Feedback Loop Epoch 950/70000, Loss: 0.008939
# Feedback Loop Epoch 1000/70000, Loss: 0.008750
# Feedback Loop Epoch 1050/70000, Loss: 0.008569
# Feedback Loop Epoch 1100/70000, Loss: 0.008420
# Feedback Loop Epoch 1150/70000, Loss: 0.008534
# Feedback Loop Epoch 1200/70000, Loss: 0.008209
# Feedback Loop Epoch 1250/70000, Loss: 0.008122
# Feedback Loop Epoch 1300/70000, Loss: 0.008051
# Feedback Loop Epoch 1350/70000, Loss: 0.007963
# Feedback Loop Epoch 1400/70000, Loss: 0.007945
# Feedback Loop Epoch 1450/70000, Loss: 0.007820
# Feedback Loop Epoch 1500/70000, Loss: 0.007741
# Feedback Loop Epoch 1550/70000, Loss: 0.007721
# Feedback Loop Epoch 1600/70000, Loss: 0.007623
# Feedback Loop Epoch 1650/70000, Loss: 0.007560
# Feedback Loop Epoch 1700/70000, Loss: 0.007502
# Feedback Loop Epoch 1750/70000, Loss: 0.010597
# Feedback Loop Epoch 1800/70000, Loss: 0.007435
# Feedback Loop Epoch 1850/70000, Loss: 0.007377
# Feedback Loop Epoch 1900/70000, Loss: 0.007331
# Feedback Loop Epoch 1950/70000, Loss: 0.007283
# Feedback Loop Epoch 2000/70000, Loss: 0.007231
# Feedback Loop Epoch 2050/70000, Loss: 0.007218
# Feedback Loop Epoch 2100/70000, Loss: 0.007169
# Feedback Loop Epoch 2150/70000, Loss: 0.007119
# Feedback Loop Epoch 2200/70000, Loss: 0.007067
# Feedback Loop Epoch 2250/70000, Loss: 0.007009
# Feedback Loop Epoch 2300/70000, Loss: 0.006947
# Feedback Loop Epoch 2350/70000, Loss: 0.007074
# Feedback Loop Epoch 2400/70000, Loss: 0.006886
# Feedback Loop Epoch 2450/70000, Loss: 0.006829
# Feedback Loop Epoch 2500/70000, Loss: 0.006772
# Feedback Loop Epoch 2550/70000, Loss: 0.006714
# Feedback Loop Epoch 2600/70000, Loss: 0.006656
# Feedback Loop Epoch 2650/70000, Loss: 0.009078
# Feedback Loop Epoch 2700/70000, Loss: 0.006622
# Feedback Loop Epoch 2750/70000, Loss: 0.006558
# Feedback Loop Epoch 2800/70000, Loss: 0.006510
# Feedback Loop Epoch 2850/70000, Loss: 0.006462
# Feedback Loop Epoch 2900/70000, Loss: 0.006414
# Feedback Loop Epoch 2950/70000, Loss: 0.006365
# Feedback Loop Epoch 3000/70000, Loss: 0.006344
# Feedback Loop Epoch 3050/70000, Loss: 0.006363
# Feedback Loop Epoch 3100/70000, Loss: 0.006283
# Feedback Loop Epoch 3150/70000, Loss: 0.006239
# Feedback Loop Epoch 3200/70000, Loss: 0.006195
# Feedback Loop Epoch 3250/70000, Loss: 0.006151
# Feedback Loop Epoch 3300/70000, Loss: 0.006106
# Feedback Loop Epoch 3350/70000, Loss: 0.006060
# Feedback Loop Epoch 3400/70000, Loss: 0.008151
# Feedback Loop Epoch 3450/70000, Loss: 0.006043
# Feedback Loop Epoch 3500/70000, Loss: 0.005992
# Feedback Loop Epoch 3550/70000, Loss: 0.005951
# Feedback Loop Epoch 3600/70000, Loss: 0.005910
# Feedback Loop Epoch 3650/70000, Loss: 0.005869
# Feedback Loop Epoch 3700/70000, Loss: 0.005827
# Feedback Loop Epoch 3750/70000, Loss: 0.005784
# Feedback Loop Epoch 3800/70000, Loss: 0.005778
# Feedback Loop Epoch 3850/70000, Loss: 0.005824
# Feedback Loop Epoch 3900/70000, Loss: 0.005716
# Feedback Loop Epoch 3950/70000, Loss: 0.005678
# Feedback Loop Epoch 4000/70000, Loss: 0.005641
# Feedback Loop Epoch 4050/70000, Loss: 0.005604
# Feedback Loop Epoch 4100/70000, Loss: 0.005568
# Feedback Loop Epoch 4150/70000, Loss: 0.005532
# Feedback Loop Epoch 4200/70000, Loss: 0.005855
# Feedback Loop Epoch 4250/70000, Loss: 0.005520
# Feedback Loop Epoch 4300/70000, Loss: 0.005482
# Feedback Loop Epoch 4350/70000, Loss: 0.005451
# Feedback Loop Epoch 4400/70000, Loss: 0.005422
# Feedback Loop Epoch 4450/70000, Loss: 0.005393
# Feedback Loop Epoch 4500/70000, Loss: 0.005364
# Feedback Loop Epoch 4550/70000, Loss: 0.005337
# Feedback Loop Epoch 4600/70000, Loss: 0.005365
# Feedback Loop Epoch 4650/70000, Loss: 0.005335
# Feedback Loop Epoch 4700/70000, Loss: 0.005309
# Feedback Loop Epoch 4750/70000, Loss: 0.005285
# Feedback Loop Epoch 4800/70000, Loss: 0.005262
# Feedback Loop Epoch 4850/70000, Loss: 0.005240
# Feedback Loop Epoch 4900/70000, Loss: 0.005218
# Feedback Loop Epoch 4950/70000, Loss: 0.005196
# Feedback Loop Epoch 5000/70000, Loss: 0.007622
# Feedback Loop Epoch 5050/70000, Loss: 0.005204
# Feedback Loop Epoch 5100/70000, Loss: 0.005181
# Feedback Loop Epoch 5150/70000, Loss: 0.005161
# Feedback Loop Epoch 5200/70000, Loss: 0.005142
# Feedback Loop Epoch 5250/70000, Loss: 0.005124
# Feedback Loop Epoch 5300/70000, Loss: 0.005106
# Feedback Loop Epoch 5350/70000, Loss: 0.005089
# Feedback Loop Epoch 5400/70000, Loss: 0.005072
# Feedback Loop Epoch 5450/70000, Loss: 0.005264
# Feedback Loop Epoch 5500/70000, Loss: 0.005078
# Feedback Loop Epoch 5550/70000, Loss: 0.005057
# Feedback Loop Epoch 5600/70000, Loss: 0.005041
# Feedback Loop Epoch 5650/70000, Loss: 0.005026
# Feedback Loop Epoch 5700/70000, Loss: 0.005011
# Feedback Loop Epoch 5750/70000, Loss: 0.004997
# Feedback Loop Epoch 5800/70000, Loss: 0.004982
# Feedback Loop Epoch 5850/70000, Loss: 0.005010
# Feedback Loop Epoch 5900/70000, Loss: 0.004992
# Feedback Loop Epoch 5950/70000, Loss: 0.004975
# Feedback Loop Epoch 6000/70000, Loss: 0.004961
# Feedback Loop Epoch 6050/70000, Loss: 0.004948
# Feedback Loop Epoch 6100/70000, Loss: 0.004935
# Feedback Loop Epoch 6150/70000, Loss: 0.004923
# Feedback Loop Epoch 6200/70000, Loss: 0.004911
# Feedback Loop Epoch 6250/70000, Loss: 0.006451
# Feedback Loop Epoch 6300/70000, Loss: 0.004931
# Feedback Loop Epoch 6350/70000, Loss: 0.004907
# Feedback Loop Epoch 6400/70000, Loss: 0.004895
# Feedback Loop Epoch 6450/70000, Loss: 0.004884
# Feedback Loop Epoch 6500/70000, Loss: 0.004873
# Feedback Loop Epoch 6550/70000, Loss: 0.004862
# Feedback Loop Epoch 6600/70000, Loss: 0.004852
# Feedback Loop Epoch 6650/70000, Loss: 0.004917
# Feedback Loop Epoch 6700/70000, Loss: 0.004920
# Feedback Loop Epoch 6750/70000, Loss: 0.004851
# Feedback Loop Epoch 6800/70000, Loss: 0.004839
# Feedback Loop Epoch 6850/70000, Loss: 0.004829
# Feedback Loop Epoch 6900/70000, Loss: 0.004819
# Feedback Loop Epoch 6950/70000, Loss: 0.004810
# Feedback Loop Epoch 7000/70000, Loss: 0.004800
# Feedback Loop Epoch 7050/70000, Loss: 0.004791
# Feedback Loop Epoch 7100/70000, Loss: 0.004971
# Feedback Loop Epoch 7150/70000, Loss: 0.004804
# Feedback Loop Epoch 7200/70000, Loss: 0.004792
# Feedback Loop Epoch 7250/70000, Loss: 0.004783
# Feedback Loop Epoch 7300/70000, Loss: 0.004774
# Feedback Loop Epoch 7350/70000, Loss: 0.004765
# Feedback Loop Epoch 7400/70000, Loss: 0.004757
# Feedback Loop Epoch 7450/70000, Loss: 0.004749
# Feedback Loop Epoch 7500/70000, Loss: 0.006810
# Feedback Loop Epoch 7550/70000, Loss: 0.004766
# Feedback Loop Epoch 7600/70000, Loss: 0.004751
# Feedback Loop Epoch 7650/70000, Loss: 0.004741
# Feedback Loop Epoch 7700/70000, Loss: 0.004733
# Feedback Loop Epoch 7750/70000, Loss: 0.004725
# Feedback Loop Epoch 7800/70000, Loss: 0.004718
# Feedback Loop Epoch 7850/70000, Loss: 0.004710
# Feedback Loop Epoch 7900/70000, Loss: 0.004703
# Feedback Loop Epoch 7950/70000, Loss: 0.004994
# Feedback Loop Epoch 8000/70000, Loss: 0.004722
# Feedback Loop Epoch 8050/70000, Loss: 0.004710
# Feedback Loop Epoch 8100/70000, Loss: 0.004701
# Feedback Loop Epoch 8150/70000, Loss: 0.004694
# Feedback Loop Epoch 8200/70000, Loss: 0.004686
# Feedback Loop Epoch 8250/70000, Loss: 0.004679
# Feedback Loop Epoch 8300/70000, Loss: 0.004673
# Feedback Loop Epoch 8350/70000, Loss: 0.004666
# Feedback Loop Epoch 8400/70000, Loss: 0.006001
# Feedback Loop Epoch 8450/70000, Loss: 0.004679
# Feedback Loop Epoch 8500/70000, Loss: 0.004668
# Feedback Loop Epoch 8550/70000, Loss: 0.004660
# Feedback Loop Epoch 8600/70000, Loss: 0.004653
# Feedback Loop Epoch 8650/70000, Loss: 0.004647
# Feedback Loop Epoch 8700/70000, Loss: 0.004640
# Feedback Loop Epoch 8750/70000, Loss: 0.004634
# Feedback Loop Epoch 8800/70000, Loss: 0.013463
# Feedback Loop Epoch 8850/70000, Loss: 0.004671
# Feedback Loop Epoch 8900/70000, Loss: 0.004642
# Feedback Loop Epoch 8950/70000, Loss: 0.004634
# Feedback Loop Epoch 9000/70000, Loss: 0.004627
# Feedback Loop Epoch 9050/70000, Loss: 0.004620
# Feedback Loop Epoch 9100/70000, Loss: 0.004614
# Feedback Loop Epoch 9150/70000, Loss: 0.004608
# Feedback Loop Epoch 9200/70000, Loss: 0.004602
# Feedback Loop Epoch 9250/70000, Loss: 0.004627
# Feedback Loop Epoch 9300/70000, Loss: 0.004628
# Feedback Loop Epoch 9350/70000, Loss: 0.004608
# Feedback Loop Epoch 9400/70000, Loss: 0.004601
# Feedback Loop Epoch 9450/70000, Loss: 0.004595
# Feedback Loop Epoch 9500/70000, Loss: 0.004589
# Feedback Loop Epoch 9550/70000, Loss: 0.004583
# Feedback Loop Epoch 9600/70000, Loss: 0.004577
# Feedback Loop Epoch 9650/70000, Loss: 0.004572
# Feedback Loop Epoch 9700/70000, Loss: 0.004620
# Feedback Loop Epoch 9750/70000, Loss: 0.004600
# Feedback Loop Epoch 9800/70000, Loss: 0.004583
# Feedback Loop Epoch 9850/70000, Loss: 0.004576
# Feedback Loop Epoch 9900/70000, Loss: 0.004569
# Feedback Loop Epoch 9950/70000, Loss: 0.004564
# Feedback Loop Epoch 10000/70000, Loss: 0.004558
# Feedback Loop Epoch 10050/70000, Loss: 0.004553
# Feedback Loop Epoch 10100/70000, Loss: 0.004548
# Feedback Loop Epoch 10150/70000, Loss: 0.004543
# Feedback Loop Epoch 10200/70000, Loss: 0.004581
# Feedback Loop Epoch 10250/70000, Loss: 0.004561
# Feedback Loop Epoch 10300/70000, Loss: 0.004552
# Feedback Loop Epoch 10350/70000, Loss: 0.004545
# Feedback Loop Epoch 10400/70000, Loss: 0.004540
# Feedback Loop Epoch 10450/70000, Loss: 0.004534
# Feedback Loop Epoch 10500/70000, Loss: 0.004529
# Feedback Loop Epoch 10550/70000, Loss: 0.004524
# Feedback Loop Epoch 10600/70000, Loss: 0.004520
# Feedback Loop Epoch 10650/70000, Loss: 0.007547
# Feedback Loop Epoch 10700/70000, Loss: 0.004543
# Feedback Loop Epoch 10750/70000, Loss: 0.004527
# Feedback Loop Epoch 10800/70000, Loss: 0.004520
# Feedback Loop Epoch 10850/70000, Loss: 0.004515
# Feedback Loop Epoch 10900/70000, Loss: 0.004510
# Feedback Loop Epoch 10950/70000, Loss: 0.004505
# Feedback Loop Epoch 11000/70000, Loss: 0.004500
# Feedback Loop Epoch 11050/70000, Loss: 0.004496
# Feedback Loop Epoch 11100/70000, Loss: 0.004559
# Feedback Loop Epoch 11150/70000, Loss: 0.004515
# Feedback Loop Epoch 11200/70000, Loss: 0.004506
# Feedback Loop Epoch 11250/70000, Loss: 0.004500
# Feedback Loop Epoch 11300/70000, Loss: 0.004495
# Feedback Loop Epoch 11350/70000, Loss: 0.004490
# Feedback Loop Epoch 11400/70000, Loss: 0.004486
# Feedback Loop Epoch 11450/70000, Loss: 0.004481
# Feedback Loop Epoch 11500/70000, Loss: 0.004477
# Feedback Loop Epoch 11550/70000, Loss: 0.004998
# Feedback Loop Epoch 11600/70000, Loss: 0.004495
# Feedback Loop Epoch 11650/70000, Loss: 0.004484
# Feedback Loop Epoch 11700/70000, Loss: 0.004478
# Feedback Loop Epoch 11750/70000, Loss: 0.004473
# Feedback Loop Epoch 11800/70000, Loss: 0.004469
# Feedback Loop Epoch 11850/70000, Loss: 0.004464
# Feedback Loop Epoch 11900/70000, Loss: 0.004460
# Feedback Loop Epoch 11950/70000, Loss: 0.004511
# Feedback Loop Epoch 12000/70000, Loss: 0.004502
# Feedback Loop Epoch 12050/70000, Loss: 0.004472
# Feedback Loop Epoch 12100/70000, Loss: 0.004465
# Feedback Loop Epoch 12150/70000, Loss: 0.004460
# Feedback Loop Epoch 12200/70000, Loss: 0.004455
# Feedback Loop Epoch 12250/70000, Loss: 0.004451
# Feedback Loop Epoch 12300/70000, Loss: 0.004447
# Feedback Loop Epoch 12350/70000, Loss: 0.004443
# Feedback Loop Epoch 12400/70000, Loss: 0.006195
# Feedback Loop Epoch 12450/70000, Loss: 0.004461
# Feedback Loop Epoch 12500/70000, Loss: 0.004451
# Feedback Loop Epoch 12550/70000, Loss: 0.004445
# Feedback Loop Epoch 12600/70000, Loss: 0.004441
# Feedback Loop Epoch 12650/70000, Loss: 0.004437
# Feedback Loop Epoch 12700/70000, Loss: 0.004433
# Feedback Loop Epoch 12750/70000, Loss: 0.004429
# Feedback Loop Epoch 12800/70000, Loss: 0.004425
# Feedback Loop Epoch 12850/70000, Loss: 0.004479
# Feedback Loop Epoch 12900/70000, Loss: 0.004441
# Feedback Loop Epoch 12950/70000, Loss: 0.004434
# Feedback Loop Epoch 13000/70000, Loss: 0.004428
# Feedback Loop Epoch 13050/70000, Loss: 0.004424
# Feedback Loop Epoch 13100/70000, Loss: 0.004420
# Feedback Loop Epoch 13150/70000, Loss: 0.004416
# Feedback Loop Epoch 13200/70000, Loss: 0.004413
# Feedback Loop Epoch 13250/70000, Loss: 0.006078
# Feedback Loop Epoch 13300/70000, Loss: 0.004433
# Feedback Loop Epoch 13350/70000, Loss: 0.004420
# Feedback Loop Epoch 13400/70000, Loss: 0.004415
# Feedback Loop Epoch 13450/70000, Loss: 0.004410
# Feedback Loop Epoch 13500/70000, Loss: 0.004407
# Feedback Loop Epoch 13550/70000, Loss: 0.004403
# Feedback Loop Epoch 13600/70000, Loss: 0.004400
# Feedback Loop Epoch 13650/70000, Loss: 0.005898
# Feedback Loop Epoch 13700/70000, Loss: 0.004421
# Feedback Loop Epoch 13750/70000, Loss: 0.004410
# Feedback Loop Epoch 13800/70000, Loss: 0.004404
# Feedback Loop Epoch 13850/70000, Loss: 0.004400
# Feedback Loop Epoch 13900/70000, Loss: 0.004396
# Feedback Loop Epoch 13950/70000, Loss: 0.004392
# Feedback Loop Epoch 14000/70000, Loss: 0.004389
# Feedback Loop Epoch 14050/70000, Loss: 0.004386
# Feedback Loop Epoch 14100/70000, Loss: 0.004521
# Feedback Loop Epoch 14150/70000, Loss: 0.004400
# Feedback Loop Epoch 14200/70000, Loss: 0.004393
# Feedback Loop Epoch 14250/70000, Loss: 0.004388
# Feedback Loop Epoch 14300/70000, Loss: 0.004385
# Feedback Loop Epoch 14350/70000, Loss: 0.004381
# Feedback Loop Epoch 14400/70000, Loss: 0.004378
# Feedback Loop Epoch 14450/70000, Loss: 0.004375
# Feedback Loop Epoch 14500/70000, Loss: 0.005587
# Feedback Loop Epoch 14550/70000, Loss: 0.004398
# Feedback Loop Epoch 14600/70000, Loss: 0.004386
# Feedback Loop Epoch 14650/70000, Loss: 0.004380
# Feedback Loop Epoch 14700/70000, Loss: 0.004376
# Feedback Loop Epoch 14750/70000, Loss: 0.004372
# Feedback Loop Epoch 14800/70000, Loss: 0.004369
# Feedback Loop Epoch 14850/70000, Loss: 0.004366
# Feedback Loop Epoch 14900/70000, Loss: 0.004363
# Feedback Loop Epoch 14950/70000, Loss: 0.004398
# Feedback Loop Epoch 15000/70000, Loss: 0.004380
# Feedback Loop Epoch 15050/70000, Loss: 0.004371
# Feedback Loop Epoch 15100/70000, Loss: 0.004367
# Feedback Loop Epoch 15150/70000, Loss: 0.004363
# Feedback Loop Epoch 15200/70000, Loss: 0.004359
# Feedback Loop Epoch 15250/70000, Loss: 0.004356
# Feedback Loop Epoch 15300/70000, Loss: 0.004353
# Feedback Loop Epoch 15350/70000, Loss: 0.004350
# Feedback Loop Epoch 15400/70000, Loss: 0.004388
# Feedback Loop Epoch 15450/70000, Loss: 0.004368
# Feedback Loop Epoch 15500/70000, Loss: 0.004360
# Feedback Loop Epoch 15550/70000, Loss: 0.004355
# Feedback Loop Epoch 15600/70000, Loss: 0.004352
# Feedback Loop Epoch 15650/70000, Loss: 0.004349
# Feedback Loop Epoch 15700/70000, Loss: 0.004346
# Feedback Loop Epoch 15750/70000, Loss: 0.004343
# Feedback Loop Epoch 15800/70000, Loss: 0.004345
# Feedback Loop Epoch 15850/70000, Loss: 0.004415
# Feedback Loop Epoch 15900/70000, Loss: 0.004353
# Feedback Loop Epoch 15950/70000, Loss: 0.004348
# Feedback Loop Epoch 16000/70000, Loss: 0.004344
# Feedback Loop Epoch 16050/70000, Loss: 0.004340
# Feedback Loop Epoch 16100/70000, Loss: 0.004337
# Feedback Loop Epoch 16150/70000, Loss: 0.004334
# Feedback Loop Epoch 16200/70000, Loss: 0.004331
# Feedback Loop Epoch 16250/70000, Loss: 0.006728
# Feedback Loop Epoch 16300/70000, Loss: 0.004358
# Feedback Loop Epoch 16350/70000, Loss: 0.004340
# Feedback Loop Epoch 16400/70000, Loss: 0.004335
# Feedback Loop Epoch 16450/70000, Loss: 0.004331
# Feedback Loop Epoch 16500/70000, Loss: 0.004328
# Feedback Loop Epoch 16550/70000, Loss: 0.004325
# Feedback Loop Epoch 16600/70000, Loss: 0.004323
# Feedback Loop Epoch 16650/70000, Loss: 0.005024
# Feedback Loop Epoch 16700/70000, Loss: 0.004349
# Feedback Loop Epoch 16750/70000, Loss: 0.004332
# Feedback Loop Epoch 16800/70000, Loss: 0.004327
# Feedback Loop Epoch 16850/70000, Loss: 0.004324
# Feedback Loop Epoch 16900/70000, Loss: 0.004321
# Feedback Loop Epoch 16950/70000, Loss: 0.004318
# Feedback Loop Epoch 17000/70000, Loss: 0.004315
# Feedback Loop Epoch 17050/70000, Loss: 0.004312
# Feedback Loop Epoch 17100/70000, Loss: 0.004647
# Feedback Loop Epoch 17150/70000, Loss: 0.004330
# Feedback Loop Epoch 17200/70000, Loss: 0.004322
# Feedback Loop Epoch 17250/70000, Loss: 0.004318
# Feedback Loop Epoch 17300/70000, Loss: 0.004314
# Feedback Loop Epoch 17350/70000, Loss: 0.004311
# Feedback Loop Epoch 17400/70000, Loss: 0.004309
# Feedback Loop Epoch 17450/70000, Loss: 0.004306
# Feedback Loop Epoch 17500/70000, Loss: 0.004303
# Feedback Loop Epoch 17550/70000, Loss: 0.004411
# Feedback Loop Epoch 17600/70000, Loss: 0.004316
# Feedback Loop Epoch 17650/70000, Loss: 0.004310
# Feedback Loop Epoch 17700/70000, Loss: 0.004306
# Feedback Loop Epoch 17750/70000, Loss: 0.004303
# Feedback Loop Epoch 17800/70000, Loss: 0.004300
# Feedback Loop Epoch 17850/70000, Loss: 0.004297
# Feedback Loop Epoch 17900/70000, Loss: 0.004295
# Feedback Loop Epoch 17950/70000, Loss: 0.004323
# Feedback Loop Epoch 18000/70000, Loss: 0.004309
# Feedback Loop Epoch 18050/70000, Loss: 0.004303
# Feedback Loop Epoch 18100/70000, Loss: 0.004299
# Feedback Loop Epoch 18150/70000, Loss: 0.004296
# Feedback Loop Epoch 18200/70000, Loss: 0.004293
# Feedback Loop Epoch 18250/70000, Loss: 0.004291
# Feedback Loop Epoch 18300/70000, Loss: 0.004288
# Feedback Loop Epoch 18350/70000, Loss: 0.004363
# Feedback Loop Epoch 18400/70000, Loss: 0.004305
# Feedback Loop Epoch 18450/70000, Loss: 0.004295
# Feedback Loop Epoch 18500/70000, Loss: 0.004291
# Feedback Loop Epoch 18550/70000, Loss: 0.004288
# Feedback Loop Epoch 18600/70000, Loss: 0.004286
# Feedback Loop Epoch 18650/70000, Loss: 0.004283
# Feedback Loop Epoch 18700/70000, Loss: 0.004280
# Feedback Loop Epoch 18750/70000, Loss: 0.005275
# Feedback Loop Epoch 18800/70000, Loss: 0.004295
# Feedback Loop Epoch 18850/70000, Loss: 0.004288
# Feedback Loop Epoch 18900/70000, Loss: 0.004284
# Feedback Loop Epoch 18950/70000, Loss: 0.004281
# Feedback Loop Epoch 19000/70000, Loss: 0.004278
# Feedback Loop Epoch 19050/70000, Loss: 0.004276
# Feedback Loop Epoch 19100/70000, Loss: 0.004273
# Feedback Loop Epoch 19150/70000, Loss: 0.004428
# Feedback Loop Epoch 19200/70000, Loss: 0.004286
# Feedback Loop Epoch 19250/70000, Loss: 0.004280
# Feedback Loop Epoch 19300/70000, Loss: 0.004276
# Feedback Loop Epoch 19350/70000, Loss: 0.004273
# Feedback Loop Epoch 19400/70000, Loss: 0.004270
# Feedback Loop Epoch 19450/70000, Loss: 0.004268
# Feedback Loop Epoch 19500/70000, Loss: 0.004265
# Feedback Loop Epoch 19550/70000, Loss: 0.004329
# Feedback Loop Epoch 19600/70000, Loss: 0.004277
# Feedback Loop Epoch 19650/70000, Loss: 0.004272
# Feedback Loop Epoch 19700/70000, Loss: 0.004268
# Feedback Loop Epoch 19750/70000, Loss: 0.004265
# Feedback Loop Epoch 19800/70000, Loss: 0.004263
# Feedback Loop Epoch 19850/70000, Loss: 0.004260
# Feedback Loop Epoch 19900/70000, Loss: 0.006306
# Feedback Loop Epoch 19950/70000, Loss: 0.004284
# Feedback Loop Epoch 20000/70000, Loss: 0.004270
# Feedback Loop Epoch 20050/70000, Loss: 0.004265
# Feedback Loop Epoch 20100/70000, Loss: 0.004262
# Feedback Loop Epoch 20150/70000, Loss: 0.004259
# Feedback Loop Epoch 20200/70000, Loss: 0.004257
# Feedback Loop Epoch 20250/70000, Loss: 0.004254
# Feedback Loop Epoch 20300/70000, Loss: 0.004252
# Feedback Loop Epoch 20350/70000, Loss: 0.004312
# Feedback Loop Epoch 20400/70000, Loss: 0.004263
# Feedback Loop Epoch 20450/70000, Loss: 0.004258
# Feedback Loop Epoch 20500/70000, Loss: 0.004255
# Feedback Loop Epoch 20550/70000, Loss: 0.004252
# Feedback Loop Epoch 20600/70000, Loss: 0.004249
# Feedback Loop Epoch 20650/70000, Loss: 0.004247
# Feedback Loop Epoch 20700/70000, Loss: 0.004252
# Feedback Loop Epoch 20750/70000, Loss: 0.004266
# Feedback Loop Epoch 20800/70000, Loss: 0.004255
# Feedback Loop Epoch 20850/70000, Loss: 0.004251
# Feedback Loop Epoch 20900/70000, Loss: 0.004247
# Feedback Loop Epoch 20950/70000, Loss: 0.004245
# Feedback Loop Epoch 21000/70000, Loss: 0.004242
# Feedback Loop Epoch 21050/70000, Loss: 0.004240
# Feedback Loop Epoch 21100/70000, Loss: 0.004363
# Feedback Loop Epoch 21150/70000, Loss: 0.004261
# Feedback Loop Epoch 21200/70000, Loss: 0.004249
# Feedback Loop Epoch 21250/70000, Loss: 0.004245
# Feedback Loop Epoch 21300/70000, Loss: 0.004242
# Feedback Loop Epoch 21350/70000, Loss: 0.004239
# Feedback Loop Epoch 21400/70000, Loss: 0.004237
# Feedback Loop Epoch 21450/70000, Loss: 0.004234
# Feedback Loop Epoch 21500/70000, Loss: 0.004232
# Feedback Loop Epoch 21550/70000, Loss: 0.004368
# Feedback Loop Epoch 21600/70000, Loss: 0.004253
# Feedback Loop Epoch 21650/70000, Loss: 0.004244
# Feedback Loop Epoch 21700/70000, Loss: 0.004240
# Feedback Loop Epoch 21750/70000, Loss: 0.004236
# Feedback Loop Epoch 21800/70000, Loss: 0.004234
# Feedback Loop Epoch 21850/70000, Loss: 0.004231
# Feedback Loop Epoch 21900/70000, Loss: 0.004229
# Feedback Loop Epoch 21950/70000, Loss: 0.004227
# Feedback Loop Epoch 22000/70000, Loss: 0.004224
# Feedback Loop Epoch 22050/70000, Loss: 0.004269
# Feedback Loop Epoch 22100/70000, Loss: 0.004238
# Feedback Loop Epoch 22150/70000, Loss: 0.004232
# Feedback Loop Epoch 22200/70000, Loss: 0.004229
# Feedback Loop Epoch 22250/70000, Loss: 0.004226
# Feedback Loop Epoch 22300/70000, Loss: 0.004224
# Feedback Loop Epoch 22350/70000, Loss: 0.004221
# Feedback Loop Epoch 22400/70000, Loss: 0.004219
# Feedback Loop Epoch 22450/70000, Loss: 0.004898
# Feedback Loop Epoch 22500/70000, Loss: 0.004251
# Feedback Loop Epoch 22550/70000, Loss: 0.004227
# Feedback Loop Epoch 22600/70000, Loss: 0.004223
# Feedback Loop Epoch 22650/70000, Loss: 0.004220
# Feedback Loop Epoch 22700/70000, Loss: 0.004218
# Feedback Loop Epoch 22750/70000, Loss: 0.004215
# Feedback Loop Epoch 22800/70000, Loss: 0.004213
# Feedback Loop Epoch 22850/70000, Loss: 0.004284
# Feedback Loop Epoch 22900/70000, Loss: 0.004241
# Feedback Loop Epoch 22950/70000, Loss: 0.004224
# Feedback Loop Epoch 23000/70000, Loss: 0.004220
# Feedback Loop Epoch 23050/70000, Loss: 0.004216
# Feedback Loop Epoch 23100/70000, Loss: 0.004214
# Feedback Loop Epoch 23150/70000, Loss: 0.004211
# Feedback Loop Epoch 23200/70000, Loss: 0.004209
# Feedback Loop Epoch 23250/70000, Loss: 0.004207
# Feedback Loop Epoch 23300/70000, Loss: 0.004245
# Feedback Loop Epoch 23350/70000, Loss: 0.004228
# Feedback Loop Epoch 23400/70000, Loss: 0.004216
# Feedback Loop Epoch 23450/70000, Loss: 0.004212
# Feedback Loop Epoch 23500/70000, Loss: 0.004209
# Feedback Loop Epoch 23550/70000, Loss: 0.004206
# Feedback Loop Epoch 23600/70000, Loss: 0.004204
# Feedback Loop Epoch 23650/70000, Loss: 0.004202
# Feedback Loop Epoch 23700/70000, Loss: 0.004200
# Feedback Loop Epoch 23750/70000, Loss: 0.004941
# Feedback Loop Epoch 23800/70000, Loss: 0.004214
# Feedback Loop Epoch 23850/70000, Loss: 0.004206
# Feedback Loop Epoch 23900/70000, Loss: 0.004203
# Feedback Loop Epoch 23950/70000, Loss: 0.004200
# Feedback Loop Epoch 24000/70000, Loss: 0.004198
# Feedback Loop Epoch 24050/70000, Loss: 0.004195
# Feedback Loop Epoch 24100/70000, Loss: 0.004194
# Feedback Loop Epoch 24150/70000, Loss: 0.004263
# Feedback Loop Epoch 24200/70000, Loss: 0.004204
# Feedback Loop Epoch 24250/70000, Loss: 0.004199
# Feedback Loop Epoch 24300/70000, Loss: 0.004197
# Feedback Loop Epoch 24350/70000, Loss: 0.004194
# Feedback Loop Epoch 24400/70000, Loss: 0.004192
# Feedback Loop Epoch 24450/70000, Loss: 0.004190
# Feedback Loop Epoch 24500/70000, Loss: 0.008235
# Feedback Loop Epoch 24550/70000, Loss: 0.004207
# Feedback Loop Epoch 24600/70000, Loss: 0.004197
# Feedback Loop Epoch 24650/70000, Loss: 0.004193
# Feedback Loop Epoch 24700/70000, Loss: 0.004191
# Feedback Loop Epoch 24750/70000, Loss: 0.004188
# Feedback Loop Epoch 24800/70000, Loss: 0.004186
# Feedback Loop Epoch 24850/70000, Loss: 0.004184
# Feedback Loop Epoch 24900/70000, Loss: 0.004402
# Feedback Loop Epoch 24950/70000, Loss: 0.004198
# Feedback Loop Epoch 25000/70000, Loss: 0.004191
# Feedback Loop Epoch 25050/70000, Loss: 0.004188
# Feedback Loop Epoch 25100/70000, Loss: 0.004185
# Feedback Loop Epoch 25150/70000, Loss: 0.004183
# Feedback Loop Epoch 25200/70000, Loss: 0.004181
# Feedback Loop Epoch 25250/70000, Loss: 0.004179
# Feedback Loop Epoch 25300/70000, Loss: 0.005259
# Feedback Loop Epoch 25350/70000, Loss: 0.004200
# Feedback Loop Epoch 25400/70000, Loss: 0.004187
# Feedback Loop Epoch 25450/70000, Loss: 0.004184
# Feedback Loop Epoch 25500/70000, Loss: 0.004181
# Feedback Loop Epoch 25550/70000, Loss: 0.004178
# Feedback Loop Epoch 25600/70000, Loss: 0.004176
# Feedback Loop Epoch 25650/70000, Loss: 0.004174
# Feedback Loop Epoch 25700/70000, Loss: 0.004177
# Feedback Loop Epoch 25750/70000, Loss: 0.004189
# Feedback Loop Epoch 25800/70000, Loss: 0.004181
# Feedback Loop Epoch 25850/70000, Loss: 0.004178
# Feedback Loop Epoch 25900/70000, Loss: 0.004175
# Feedback Loop Epoch 25950/70000, Loss: 0.004173
# Feedback Loop Epoch 26000/70000, Loss: 0.004170
# Feedback Loop Epoch 26050/70000, Loss: 0.004168
# Feedback Loop Epoch 26100/70000, Loss: 0.006128
# Feedback Loop Epoch 26150/70000, Loss: 0.004183
# Feedback Loop Epoch 26200/70000, Loss: 0.004176
# Feedback Loop Epoch 26250/70000, Loss: 0.004173
# Feedback Loop Epoch 26300/70000, Loss: 0.004170
# Feedback Loop Epoch 26350/70000, Loss: 0.004168
# Feedback Loop Epoch 26400/70000, Loss: 0.004165
# Feedback Loop Epoch 26450/70000, Loss: 0.004163
# Feedback Loop Epoch 26500/70000, Loss: 0.004278
# Feedback Loop Epoch 26550/70000, Loss: 0.004178
# Feedback Loop Epoch 26600/70000, Loss: 0.004170
# Feedback Loop Epoch 26650/70000, Loss: 0.004167
# Feedback Loop Epoch 26700/70000, Loss: 0.004164
# Feedback Loop Epoch 26750/70000, Loss: 0.004162
# Feedback Loop Epoch 26800/70000, Loss: 0.004160
# Feedback Loop Epoch 26850/70000, Loss: 0.004158
# Feedback Loop Epoch 26900/70000, Loss: 0.004274
# Feedback Loop Epoch 26950/70000, Loss: 0.004168
# Feedback Loop Epoch 27000/70000, Loss: 0.004164
# Feedback Loop Epoch 27050/70000, Loss: 0.004161
# Feedback Loop Epoch 27100/70000, Loss: 0.004158
# Feedback Loop Epoch 27150/70000, Loss: 0.004156
# Feedback Loop Epoch 27200/70000, Loss: 0.004154
# Feedback Loop Epoch 27250/70000, Loss: 0.007396
# Feedback Loop Epoch 27300/70000, Loss: 0.004174
# Feedback Loop Epoch 27350/70000, Loss: 0.004161
# Feedback Loop Epoch 27400/70000, Loss: 0.004158
# Feedback Loop Epoch 27450/70000, Loss: 0.004155
# Feedback Loop Epoch 27500/70000, Loss: 0.004153
# Feedback Loop Epoch 27550/70000, Loss: 0.004151
# Feedback Loop Epoch 27600/70000, Loss: 0.004149
# Feedback Loop Epoch 27650/70000, Loss: 0.006012
# Feedback Loop Epoch 27700/70000, Loss: 0.004169
# Feedback Loop Epoch 27750/70000, Loss: 0.004161
# Feedback Loop Epoch 27800/70000, Loss: 0.004156
# Feedback Loop Epoch 27850/70000, Loss: 0.004153
# Feedback Loop Epoch 27900/70000, Loss: 0.004151
# Feedback Loop Epoch 27950/70000, Loss: 0.004149
# Feedback Loop Epoch 28000/70000, Loss: 0.004147
# Feedback Loop Epoch 28050/70000, Loss: 0.004144
# Feedback Loop Epoch 28100/70000, Loss: 0.004143
# Feedback Loop Epoch 28150/70000, Loss: 0.004160
# Feedback Loop Epoch 28200/70000, Loss: 0.004152
# Feedback Loop Epoch 28250/70000, Loss: 0.004148
# Feedback Loop Epoch 28300/70000, Loss: 0.004146
# Feedback Loop Epoch 28350/70000, Loss: 0.004143
# Feedback Loop Epoch 28400/70000, Loss: 0.004141
# Feedback Loop Epoch 28450/70000, Loss: 0.004139
# Feedback Loop Epoch 28500/70000, Loss: 0.004142
# Feedback Loop Epoch 28550/70000, Loss: 0.004171
# Feedback Loop Epoch 28600/70000, Loss: 0.004147
# Feedback Loop Epoch 28650/70000, Loss: 0.004143
# Feedback Loop Epoch 28700/70000, Loss: 0.004140
# Feedback Loop Epoch 28750/70000, Loss: 0.004138
# Feedback Loop Epoch 28800/70000, Loss: 0.004136
# Feedback Loop Epoch 28850/70000, Loss: 0.004134
# Feedback Loop Epoch 28900/70000, Loss: 0.004165
# Feedback Loop Epoch 28950/70000, Loss: 0.004152
# Feedback Loop Epoch 29000/70000, Loss: 0.004141
# Feedback Loop Epoch 29050/70000, Loss: 0.004138
# Feedback Loop Epoch 29100/70000, Loss: 0.004135
# Feedback Loop Epoch 29150/70000, Loss: 0.004133
# Feedback Loop Epoch 29200/70000, Loss: 0.004131
# Feedback Loop Epoch 29250/70000, Loss: 0.004129
# Feedback Loop Epoch 29300/70000, Loss: 0.004183
# Feedback Loop Epoch 29350/70000, Loss: 0.004143
# Feedback Loop Epoch 29400/70000, Loss: 0.004135
# Feedback Loop Epoch 29450/70000, Loss: 0.004132
# Feedback Loop Epoch 29500/70000, Loss: 0.004130
# Feedback Loop Epoch 29550/70000, Loss: 0.004128
# Feedback Loop Epoch 29600/70000, Loss: 0.004126
# Feedback Loop Epoch 29650/70000, Loss: 0.004124
# Feedback Loop Epoch 29700/70000, Loss: 0.004214
# Feedback Loop Epoch 29750/70000, Loss: 0.004133
# Feedback Loop Epoch 29800/70000, Loss: 0.004129
# Feedback Loop Epoch 29850/70000, Loss: 0.004126
# Feedback Loop Epoch 29900/70000, Loss: 0.004124
# Feedback Loop Epoch 29950/70000, Loss: 0.004122
# Feedback Loop Epoch 30000/70000, Loss: 0.004120
# Feedback Loop Epoch 30050/70000, Loss: 0.004300
# Feedback Loop Epoch 30100/70000, Loss: 0.004141
# Feedback Loop Epoch 30150/70000, Loss: 0.004127
# Feedback Loop Epoch 30200/70000, Loss: 0.004124
# Feedback Loop Epoch 30250/70000, Loss: 0.004122
# Feedback Loop Epoch 30300/70000, Loss: 0.004119
# Feedback Loop Epoch 30350/70000, Loss: 0.004117
# Feedback Loop Epoch 30400/70000, Loss: 0.004115
# Feedback Loop Epoch 30450/70000, Loss: 0.006854
# Feedback Loop Epoch 30500/70000, Loss: 0.004133
# Feedback Loop Epoch 30550/70000, Loss: 0.004125
# Feedback Loop Epoch 30600/70000, Loss: 0.004121
# Feedback Loop Epoch 30650/70000, Loss: 0.004119
# Feedback Loop Epoch 30700/70000, Loss: 0.004116
# Feedback Loop Epoch 30750/70000, Loss: 0.004114
# Feedback Loop Epoch 30800/70000, Loss: 0.004112
# Feedback Loop Epoch 30850/70000, Loss: 0.004110
# Feedback Loop Epoch 30900/70000, Loss: 0.007526
# Feedback Loop Epoch 30950/70000, Loss: 0.004136
# Feedback Loop Epoch 31000/70000, Loss: 0.004118
# Feedback Loop Epoch 31050/70000, Loss: 0.004114
# Feedback Loop Epoch 31100/70000, Loss: 0.004112
# Feedback Loop Epoch 31150/70000, Loss: 0.004110
# Feedback Loop Epoch 31200/70000, Loss: 0.004107
# Feedback Loop Epoch 31250/70000, Loss: 0.004105
# Feedback Loop Epoch 31300/70000, Loss: 0.004103
# Feedback Loop Epoch 31350/70000, Loss: 0.004156
# Feedback Loop Epoch 31400/70000, Loss: 0.004117
# Feedback Loop Epoch 31450/70000, Loss: 0.004111
# Feedback Loop Epoch 31500/70000, Loss: 0.004108
# Feedback Loop Epoch 31550/70000, Loss: 0.004106
# Feedback Loop Epoch 31600/70000, Loss: 0.004104
# Feedback Loop Epoch 31650/70000, Loss: 0.004102
# Feedback Loop Epoch 31700/70000, Loss: 0.004100
# Feedback Loop Epoch 31750/70000, Loss: 0.007384
# Feedback Loop Epoch 31800/70000, Loss: 0.004121
# Feedback Loop Epoch 31850/70000, Loss: 0.004106
# Feedback Loop Epoch 31900/70000, Loss: 0.004103
# Feedback Loop Epoch 31950/70000, Loss: 0.004100
# Feedback Loop Epoch 32000/70000, Loss: 0.004098
# Feedback Loop Epoch 32050/70000, Loss: 0.004096
# Feedback Loop Epoch 32100/70000, Loss: 0.004094
# Feedback Loop Epoch 32150/70000, Loss: 0.004116
# Feedback Loop Epoch 32200/70000, Loss: 0.004103
# Feedback Loop Epoch 32250/70000, Loss: 0.004099
# Feedback Loop Epoch 32300/70000, Loss: 0.004097
# Feedback Loop Epoch 32350/70000, Loss: 0.004094
# Feedback Loop Epoch 32400/70000, Loss: 0.004092
# Feedback Loop Epoch 32450/70000, Loss: 0.004090
# Feedback Loop Epoch 32500/70000, Loss: 0.008590
# Feedback Loop Epoch 32550/70000, Loss: 0.004111
# Feedback Loop Epoch 32600/70000, Loss: 0.004099
# Feedback Loop Epoch 32650/70000, Loss: 0.004096
# Feedback Loop Epoch 32700/70000, Loss: 0.004093
# Feedback Loop Epoch 32750/70000, Loss: 0.004090
# Feedback Loop Epoch 32800/70000, Loss: 0.004088
# Feedback Loop Epoch 32850/70000, Loss: 0.004086
# Feedback Loop Epoch 32900/70000, Loss: 0.004084
# Feedback Loop Epoch 32950/70000, Loss: 0.004169
# Feedback Loop Epoch 33000/70000, Loss: 0.004094
# Feedback Loop Epoch 33050/70000, Loss: 0.004090
# Feedback Loop Epoch 33100/70000, Loss: 0.004087
# Feedback Loop Epoch 33150/70000, Loss: 0.004085
# Feedback Loop Epoch 33200/70000, Loss: 0.004083
# Feedback Loop Epoch 33250/70000, Loss: 0.004081
# Feedback Loop Epoch 33300/70000, Loss: 0.004079
# Feedback Loop Epoch 33350/70000, Loss: 0.004144
# Feedback Loop Epoch 33400/70000, Loss: 0.004090
# Feedback Loop Epoch 33450/70000, Loss: 0.004086
# Feedback Loop Epoch 33500/70000, Loss: 0.004083
# Feedback Loop Epoch 33550/70000, Loss: 0.004081
# Feedback Loop Epoch 33600/70000, Loss: 0.004078
# Feedback Loop Epoch 33650/70000, Loss: 0.004076
# Feedback Loop Epoch 33700/70000, Loss: 0.004074
# Feedback Loop Epoch 33750/70000, Loss: 0.004336
# Feedback Loop Epoch 33800/70000, Loss: 0.004085
# Feedback Loop Epoch 33850/70000, Loss: 0.004080
# Feedback Loop Epoch 33900/70000, Loss: 0.004077
# Feedback Loop Epoch 33950/70000, Loss: 0.004075
# Feedback Loop Epoch 34000/70000, Loss: 0.004073
# Feedback Loop Epoch 34050/70000, Loss: 0.004071
# Feedback Loop Epoch 34100/70000, Loss: 0.004069
# Feedback Loop Epoch 34150/70000, Loss: 0.004137
# Feedback Loop Epoch 34200/70000, Loss: 0.004078
# Feedback Loop Epoch 34250/70000, Loss: 0.004074
# Feedback Loop Epoch 34300/70000, Loss: 0.004071
# Feedback Loop Epoch 34350/70000, Loss: 0.004069
# Feedback Loop Epoch 34400/70000, Loss: 0.004067
# Feedback Loop Epoch 34450/70000, Loss: 0.004065
# Feedback Loop Epoch 34500/70000, Loss: 0.004097
# Feedback Loop Epoch 34550/70000, Loss: 0.004077
# Feedback Loop Epoch 34600/70000, Loss: 0.004072
# Feedback Loop Epoch 34650/70000, Loss: 0.004069
# Feedback Loop Epoch 34700/70000, Loss: 0.004066
# Feedback Loop Epoch 34750/70000, Loss: 0.004064
# Feedback Loop Epoch 34800/70000, Loss: 0.004062
# Feedback Loop Epoch 34850/70000, Loss: 0.004059
# Feedback Loop Epoch 34900/70000, Loss: 0.004117
# Feedback Loop Epoch 34950/70000, Loss: 0.004073
# Feedback Loop Epoch 35000/70000, Loss: 0.004067
# Feedback Loop Epoch 35050/70000, Loss: 0.004064
# Feedback Loop Epoch 35100/70000, Loss: 0.004061
# Feedback Loop Epoch 35150/70000, Loss: 0.004059
# Feedback Loop Epoch 35200/70000, Loss: 0.004057
# Feedback Loop Epoch 35250/70000, Loss: 0.004055
# Feedback Loop Epoch 35300/70000, Loss: 0.004544
# Feedback Loop Epoch 35350/70000, Loss: 0.004070
# Feedback Loop Epoch 35400/70000, Loss: 0.004064
# Feedback Loop Epoch 35450/70000, Loss: 0.004060
# Feedback Loop Epoch 35500/70000, Loss: 0.004057
# Feedback Loop Epoch 35550/70000, Loss: 0.004055
# Feedback Loop Epoch 35600/70000, Loss: 0.004053
# Feedback Loop Epoch 35650/70000, Loss: 0.004051
# Feedback Loop Epoch 35700/70000, Loss: 0.004049
# Feedback Loop Epoch 35750/70000, Loss: 0.004160
# Feedback Loop Epoch 35800/70000, Loss: 0.004058
# Feedback Loop Epoch 35850/70000, Loss: 0.004054
# Feedback Loop Epoch 35900/70000, Loss: 0.004051
# Feedback Loop Epoch 35950/70000, Loss: 0.004049
# Feedback Loop Epoch 36000/70000, Loss: 0.004047
# Feedback Loop Epoch 36050/70000, Loss: 0.004045
# Feedback Loop Epoch 36100/70000, Loss: 0.004182
# Feedback Loop Epoch 36150/70000, Loss: 0.004068
# Feedback Loop Epoch 36200/70000, Loss: 0.004051
# Feedback Loop Epoch 36250/70000, Loss: 0.004048
# Feedback Loop Epoch 36300/70000, Loss: 0.004045
# Feedback Loop Epoch 36350/70000, Loss: 0.004043
# Feedback Loop Epoch 36400/70000, Loss: 0.004041
# Feedback Loop Epoch 36450/70000, Loss: 0.004039
# Feedback Loop Epoch 36500/70000, Loss: 0.004097
# Feedback Loop Epoch 36550/70000, Loss: 0.004049
# Feedback Loop Epoch 36600/70000, Loss: 0.004045
# Feedback Loop Epoch 36650/70000, Loss: 0.004042
# Feedback Loop Epoch 36700/70000, Loss: 0.004040
# Feedback Loop Epoch 36750/70000, Loss: 0.004037
# Feedback Loop Epoch 36800/70000, Loss: 0.004035
# Feedback Loop Epoch 36850/70000, Loss: 0.004033
# Feedback Loop Epoch 36900/70000, Loss: 0.004053
# Feedback Loop Epoch 36950/70000, Loss: 0.004043
# Feedback Loop Epoch 37000/70000, Loss: 0.004039
# Feedback Loop Epoch 37050/70000, Loss: 0.004036
# Feedback Loop Epoch 37100/70000, Loss: 0.004034
# Feedback Loop Epoch 37150/70000, Loss: 0.004031
# Feedback Loop Epoch 37200/70000, Loss: 0.004029
# Feedback Loop Epoch 37250/70000, Loss: 0.004226
# Feedback Loop Epoch 37300/70000, Loss: 0.004043
# Feedback Loop Epoch 37350/70000, Loss: 0.004036
# Feedback Loop Epoch 37400/70000, Loss: 0.004033
# Feedback Loop Epoch 37450/70000, Loss: 0.004030
# Feedback Loop Epoch 37500/70000, Loss: 0.004028
# Feedback Loop Epoch 37550/70000, Loss: 0.004026
# Feedback Loop Epoch 37600/70000, Loss: 0.004023
# Feedback Loop Epoch 37650/70000, Loss: 0.004099
# Feedback Loop Epoch 37700/70000, Loss: 0.004035
# Feedback Loop Epoch 37750/70000, Loss: 0.004030
# Feedback Loop Epoch 37800/70000, Loss: 0.004027
# Feedback Loop Epoch 37850/70000, Loss: 0.004025
# Feedback Loop Epoch 37900/70000, Loss: 0.004022
# Feedback Loop Epoch 37950/70000, Loss: 0.004020
# Feedback Loop Epoch 38000/70000, Loss: 0.004018
# Feedback Loop Epoch 38050/70000, Loss: 0.004151
# Feedback Loop Epoch 38100/70000, Loss: 0.004033
# Feedback Loop Epoch 38150/70000, Loss: 0.004027
# Feedback Loop Epoch 38200/70000, Loss: 0.004024
# Feedback Loop Epoch 38250/70000, Loss: 0.004021
# Feedback Loop Epoch 38300/70000, Loss: 0.004019
# Feedback Loop Epoch 38350/70000, Loss: 0.004016
# Feedback Loop Epoch 38400/70000, Loss: 0.004014
# Feedback Loop Epoch 38450/70000, Loss: 0.004012
# Feedback Loop Epoch 38500/70000, Loss: 0.004086
# Feedback Loop Epoch 38550/70000, Loss: 0.004026
# Feedback Loop Epoch 38600/70000, Loss: 0.004021
# Feedback Loop Epoch 38650/70000, Loss: 0.004018
# Feedback Loop Epoch 38700/70000, Loss: 0.004015
# Feedback Loop Epoch 38750/70000, Loss: 0.004013
# Feedback Loop Epoch 38800/70000, Loss: 0.004011
# Feedback Loop Epoch 38850/70000, Loss: 0.004009
# Feedback Loop Epoch 38900/70000, Loss: 0.004007
# ...
# Feedback Loop Epoch 53500/70000, Loss: 0.003788
# Feedback Loop Epoch 53550/70000, Loss: 0.003786
# Feedback Loop Epoch 53600/70000, Loss: 0.003784
# Feedback Loop Epoch 53650/70000, Loss: 0.003782
# Feedback Loop Epoch 53700/70000, Loss: 0.003927
# Feedback Loop Epoch 53750/70000, Loss: 0.003803
# Feedback Loop Epoch 53800/70000, Loss: 0.003788
# Feedback Loop Epoch 53850/70000, Loss: 0.003784
# Feedback Loop Epoch 53900/70000, Loss: 0.003782
# Feedback Loop Epoch 53950/70000, Loss: 0.003779
# Feedback Loop Epoch 54000/70000, Loss: 0.003777
# Feedback Loop Epoch 54050/70000, Loss: 0.003775
# Feedback Loop Epoch 54100/70000, Loss: 0.004216
# Feedback Loop Epoch 54150/70000, Loss: 0.003784
# Feedback Loop Epoch 54200/70000, Loss: 0.003779
# Feedback Loop Epoch 54250/70000, Loss: 0.003776
# Feedback Loop Epoch 54300/70000, Loss: 0.003773
# Feedback Loop Epoch 54350/70000, Loss: 0.003770
# Feedback Loop Epoch 54400/70000, Loss: 0.003768
# Feedback Loop Epoch 54450/70000, Loss: 0.004224
# Feedback Loop Epoch 54500/70000, Loss: 0.003785
# Feedback Loop Epoch 54550/70000, Loss: 0.003774
# Feedback Loop Epoch 54600/70000, Loss: 0.003770
# Feedback Loop Epoch 54650/70000, Loss: 0.003767
# Feedback Loop Epoch 54700/70000, Loss: 0.003765
# Feedback Loop Epoch 54750/70000, Loss: 0.003762
# Feedback Loop Epoch 54800/70000, Loss: 0.003760
# Feedback Loop Epoch 54850/70000, Loss: 0.003815
# Feedback Loop Epoch 54900/70000, Loss: 0.003771
# Feedback Loop Epoch 54950/70000, Loss: 0.003766
# Feedback Loop Epoch 55000/70000, Loss: 0.003763
# Feedback Loop Epoch 55050/70000, Loss: 0.003760
# Feedback Loop Epoch 55100/70000, Loss: 0.003757
# Feedback Loop Epoch 55150/70000, Loss: 0.003755
# Feedback Loop Epoch 55200/70000, Loss: 0.003752
# Feedback Loop Epoch 55250/70000, Loss: 0.003767
# Feedback Loop Epoch 55300/70000, Loss: 0.003761
# Feedback Loop Epoch 55350/70000, Loss: 0.003756
# Feedback Loop Epoch 55400/70000, Loss: 0.003753
# Feedback Loop Epoch 55450/70000, Loss: 0.003750
# Feedback Loop Epoch 55500/70000, Loss: 0.003747
# Feedback Loop Epoch 55550/70000, Loss: 0.003745
# Feedback Loop Epoch 55600/70000, Loss: 0.004308
# Feedback Loop Epoch 55650/70000, Loss: 0.003756
# Feedback Loop Epoch 55700/70000, Loss: 0.003748
# Feedback Loop Epoch 55750/70000, Loss: 0.003744
# Feedback Loop Epoch 55800/70000, Loss: 0.003740
# Feedback Loop Epoch 55850/70000, Loss: 0.003737
# Feedback Loop Epoch 55900/70000, Loss: 0.003734
# Feedback Loop Epoch 55950/70000, Loss: 0.004099
# Feedback Loop Epoch 56000/70000, Loss: 0.003750
# Feedback Loop Epoch 56050/70000, Loss: 0.003738
# Feedback Loop Epoch 56100/70000, Loss: 0.003733
# Feedback Loop Epoch 56150/70000, Loss: 0.003729
# Feedback Loop Epoch 56200/70000, Loss: 0.003725
# Feedback Loop Epoch 56250/70000, Loss: 0.003720
# Feedback Loop Epoch 56300/70000, Loss: 0.003716
# Feedback Loop Epoch 56350/70000, Loss: 0.003860
# Feedback Loop Epoch 56400/70000, Loss: 0.003724
# Feedback Loop Epoch 56450/70000, Loss: 0.003717
# Feedback Loop Epoch 56500/70000, Loss: 0.003712
# Feedback Loop Epoch 56550/70000, Loss: 0.003707
# Feedback Loop Epoch 56600/70000, Loss: 0.003702
# Feedback Loop Epoch 56650/70000, Loss: 0.003697
# Feedback Loop Epoch 56700/70000, Loss: 0.004575
# Feedback Loop Epoch 56750/70000, Loss: 0.003709
# Feedback Loop Epoch 56800/70000, Loss: 0.003698
# Feedback Loop Epoch 56850/70000, Loss: 0.003692
# Feedback Loop Epoch 56900/70000, Loss: 0.003686
# Feedback Loop Epoch 56950/70000, Loss: 0.003681
# Feedback Loop Epoch 57000/70000, Loss: 0.003675
# Feedback Loop Epoch 57050/70000, Loss: 0.005617
# Feedback Loop Epoch 57100/70000, Loss: 0.003685
# Feedback Loop Epoch 57150/70000, Loss: 0.003676
# Feedback Loop Epoch 57200/70000, Loss: 0.003669
# Feedback Loop Epoch 57250/70000, Loss: 0.003662
# Feedback Loop Epoch 57300/70000, Loss: 0.003656
# Feedback Loop Epoch 57350/70000, Loss: 0.003650
# Feedback Loop Epoch 57400/70000, Loss: 0.008035
# Feedback Loop Epoch 57450/70000, Loss: 0.003672
# Feedback Loop Epoch 57500/70000, Loss: 0.003650
# Feedback Loop Epoch 57550/70000, Loss: 0.003642
# Feedback Loop Epoch 57600/70000, Loss: 0.003636
# Feedback Loop Epoch 57650/70000, Loss: 0.003629
# Feedback Loop Epoch 57700/70000, Loss: 0.003623
# Feedback Loop Epoch 57750/70000, Loss: 0.004368
# Feedback Loop Epoch 57800/70000, Loss: 0.003635
# Feedback Loop Epoch 57850/70000, Loss: 0.003623
# Feedback Loop Epoch 57900/70000, Loss: 0.003615
# Feedback Loop Epoch 57950/70000, Loss: 0.003608
# Feedback Loop Epoch 58000/70000, Loss: 0.003601
# Feedback Loop Epoch 58050/70000, Loss: 0.003595
# Feedback Loop Epoch 58100/70000, Loss: 0.003900
# Feedback Loop Epoch 58150/70000, Loss: 0.003613
# Feedback Loop Epoch 58200/70000, Loss: 0.003595
# Feedback Loop Epoch 58250/70000, Loss: 0.003587
# Feedback Loop Epoch 58300/70000, Loss: 0.003580
# Feedback Loop Epoch 58350/70000, Loss: 0.003573
# Feedback Loop Epoch 58400/70000, Loss: 0.003567
# Feedback Loop Epoch 58450/70000, Loss: 0.003588
# Feedback Loop Epoch 58500/70000, Loss: 0.003610
# Feedback Loop Epoch 58550/70000, Loss: 0.003567
# Feedback Loop Epoch 58600/70000, Loss: 0.003559
# Feedback Loop Epoch 58650/70000, Loss: 0.003552
# Feedback Loop Epoch 58700/70000, Loss: 0.003545
# Feedback Loop Epoch 58750/70000, Loss: 0.003539
# Feedback Loop Epoch 58800/70000, Loss: 0.003534
# Feedback Loop Epoch 58850/70000, Loss: 0.003570
# Feedback Loop Epoch 58900/70000, Loss: 0.003541
# Feedback Loop Epoch 58950/70000, Loss: 0.003533
# Feedback Loop Epoch 59000/70000, Loss: 0.003526
# Feedback Loop Epoch 59050/70000, Loss: 0.003520
# Feedback Loop Epoch 59100/70000, Loss: 0.003514
# Feedback Loop Epoch 59150/70000, Loss: 0.003509
# Feedback Loop Epoch 59200/70000, Loss: 0.003848
# Feedback Loop Epoch 59250/70000, Loss: 0.003523
# Feedback Loop Epoch 59300/70000, Loss: 0.003513
# Feedback Loop Epoch 59350/70000, Loss: 0.003505
# Feedback Loop Epoch 59400/70000, Loss: 0.003499
# Feedback Loop Epoch 59450/70000, Loss: 0.003494
# Feedback Loop Epoch 59500/70000, Loss: 0.003488
# Feedback Loop Epoch 59550/70000, Loss: 0.003483
# Feedback Loop Epoch 59600/70000, Loss: 0.005526
# Feedback Loop Epoch 59650/70000, Loss: 0.003501
# Feedback Loop Epoch 59700/70000, Loss: 0.003484
# Feedback Loop Epoch 59750/70000, Loss: 0.003477
# Feedback Loop Epoch 59800/70000, Loss: 0.003471
# Feedback Loop Epoch 59850/70000, Loss: 0.003466
# Feedback Loop Epoch 59900/70000, Loss: 0.003461
# Feedback Loop Epoch 59950/70000, Loss: 0.003518
# Feedback Loop Epoch 60000/70000, Loss: 0.003481
# Feedback Loop Epoch 60050/70000, Loss: 0.003469
# Feedback Loop Epoch 60100/70000, Loss: 0.003461
# Feedback Loop Epoch 60150/70000, Loss: 0.003455
# Feedback Loop Epoch 60200/70000, Loss: 0.003449
# Feedback Loop Epoch 60250/70000, Loss: 0.003444
# Feedback Loop Epoch 60300/70000, Loss: 0.003440
# Feedback Loop Epoch 60350/70000, Loss: 0.003435
# Feedback Loop Epoch 60400/70000, Loss: 0.003466
# Feedback Loop Epoch 60450/70000, Loss: 0.003445
# Feedback Loop Epoch 60500/70000, Loss: 0.003437
# Feedback Loop Epoch 60550/70000, Loss: 0.003431
# Feedback Loop Epoch 60600/70000, Loss: 0.003426
# Feedback Loop Epoch 60650/70000, Loss: 0.003421
# Feedback Loop Epoch 60700/70000, Loss: 0.003417
# Feedback Loop Epoch 60750/70000, Loss: 0.003516
# Feedback Loop Epoch 60800/70000, Loss: 0.003429
# Feedback Loop Epoch 60850/70000, Loss: 0.003420
# Feedback Loop Epoch 60900/70000, Loss: 0.003414
# Feedback Loop Epoch 60950/70000, Loss: 0.003408
# Feedback Loop Epoch 61000/70000, Loss: 0.003404
# Feedback Loop Epoch 61050/70000, Loss: 0.003399
# Feedback Loop Epoch 61100/70000, Loss: 0.007768
# Feedback Loop Epoch 61150/70000, Loss: 0.003412
# Feedback Loop Epoch 61200/70000, Loss: 0.003403
# Feedback Loop Epoch 61250/70000, Loss: 0.003397
# Feedback Loop Epoch 61300/70000, Loss: 0.003392
# Feedback Loop Epoch 61350/70000, Loss: 0.003387
# Feedback Loop Epoch 61400/70000, Loss: 0.003383
# Feedback Loop Epoch 61450/70000, Loss: 0.003383
# Feedback Loop Epoch 61500/70000, Loss: 0.003437
# Feedback Loop Epoch 61550/70000, Loss: 0.003392
# Feedback Loop Epoch 61600/70000, Loss: 0.003385
# Feedback Loop Epoch 61650/70000, Loss: 0.003379
# Feedback Loop Epoch 61700/70000, Loss: 0.003375
# Feedback Loop Epoch 61750/70000, Loss: 0.003370
# Feedback Loop Epoch 61800/70000, Loss: 0.003366
# Feedback Loop Epoch 61850/70000, Loss: 0.003362
# Feedback Loop Epoch 61900/70000, Loss: 0.003409
# Feedback Loop Epoch 61950/70000, Loss: 0.003369
# Feedback Loop Epoch 62000/70000, Loss: 0.003363
# Feedback Loop Epoch 62050/70000, Loss: 0.003358
# Feedback Loop Epoch 62100/70000, Loss: 0.003354
# Feedback Loop Epoch 62150/70000, Loss: 0.003350
# Feedback Loop Epoch 62200/70000, Loss: 0.003524
# Feedback Loop Epoch 62250/70000, Loss: 0.003364
# Feedback Loop Epoch 62300/70000, Loss: 0.003354
# Feedback Loop Epoch 62350/70000, Loss: 0.003349
# Feedback Loop Epoch 62400/70000, Loss: 0.003344
# Feedback Loop Epoch 62450/70000, Loss: 0.003340
# Feedback Loop Epoch 62500/70000, Loss: 0.003336
# Feedback Loop Epoch 62550/70000, Loss: 0.003587
# Feedback Loop Epoch 62600/70000, Loss: 0.003360
# Feedback Loop Epoch 62650/70000, Loss: 0.003346
# Feedback Loop Epoch 62700/70000, Loss: 0.003339
# Feedback Loop Epoch 62750/70000, Loss: 0.003334
# Feedback Loop Epoch 62800/70000, Loss: 0.003330
# Feedback Loop Epoch 62850/70000, Loss: 0.003326
# Feedback Loop Epoch 62900/70000, Loss: 0.003322
# Feedback Loop Epoch 62950/70000, Loss: 0.003319
# Feedback Loop Epoch 63000/70000, Loss: 0.003417
# Feedback Loop Epoch 63050/70000, Loss: 0.003327
# Feedback Loop Epoch 63100/70000, Loss: 0.003322
# Feedback Loop Epoch 63150/70000, Loss: 0.003317
# Feedback Loop Epoch 63200/70000, Loss: 0.003313
# Feedback Loop Epoch 63250/70000, Loss: 0.003309
# Feedback Loop Epoch 63300/70000, Loss: 0.003306
# Feedback Loop Epoch 63350/70000, Loss: 0.003414
# Feedback Loop Epoch 63400/70000, Loss: 0.003319
# Feedback Loop Epoch 63450/70000, Loss: 0.003312
# Feedback Loop Epoch 63500/70000, Loss: 0.003307
# Feedback Loop Epoch 63550/70000, Loss: 0.003303
# Feedback Loop Epoch 63600/70000, Loss: 0.003299
# Feedback Loop Epoch 63650/70000, Loss: 0.003296
# Feedback Loop Epoch 63700/70000, Loss: 0.003293
# Feedback Loop Epoch 63750/70000, Loss: 0.003385
# Feedback Loop Epoch 63800/70000, Loss: 0.003302
# Feedback Loop Epoch 63850/70000, Loss: 0.003297
# Feedback Loop Epoch 63900/70000, Loss: 0.003292
# Feedback Loop Epoch 63950/70000, Loss: 0.003288
# Feedback Loop Epoch 64000/70000, Loss: 0.003285
# Feedback Loop Epoch 64050/70000, Loss: 0.003282
# Feedback Loop Epoch 64100/70000, Loss: 0.004097
# Feedback Loop Epoch 64150/70000, Loss: 0.003298
# Feedback Loop Epoch 64200/70000, Loss: 0.003289
# Feedback Loop Epoch 64250/70000, Loss: 0.003284
# Feedback Loop Epoch 64300/70000, Loss: 0.003280
# Feedback Loop Epoch 64350/70000, Loss: 0.003276
# Feedback Loop Epoch 64400/70000, Loss: 0.003273
# Feedback Loop Epoch 64450/70000, Loss: 0.003270
# Feedback Loop Epoch 64500/70000, Loss: 0.003365
# Feedback Loop Epoch 64550/70000, Loss: 0.003279
# Feedback Loop Epoch 64600/70000, Loss: 0.003272
# Feedback Loop Epoch 64650/70000, Loss: 0.003268
# Feedback Loop Epoch 64700/70000, Loss: 0.003264
# Feedback Loop Epoch 64750/70000, Loss: 0.003261
# Feedback Loop Epoch 64800/70000, Loss: 0.003260
# Feedback Loop Epoch 64850/70000, Loss: 0.003276
# Feedback Loop Epoch 64900/70000, Loss: 0.003268
# Feedback Loop Epoch 64950/70000, Loss: 0.003262
# Feedback Loop Epoch 65000/70000, Loss: 0.003258
# Feedback Loop Epoch 65050/70000, Loss: 0.003254
# Feedback Loop Epoch 65100/70000, Loss: 0.003251
# Feedback Loop Epoch 65150/70000, Loss: 0.003248
# Feedback Loop Epoch 65200/70000, Loss: 0.003272
# Feedback Loop Epoch 65250/70000, Loss: 0.003259
# Feedback Loop Epoch 65300/70000, Loss: 0.003253
# Feedback Loop Epoch 65350/70000, Loss: 0.003249
# Feedback Loop Epoch 65400/70000, Loss: 0.003245
# Feedback Loop Epoch 65450/70000, Loss: 0.003242
# Feedback Loop Epoch 65500/70000, Loss: 0.003239
# Feedback Loop Epoch 65550/70000, Loss: 0.003789
# Feedback Loop Epoch 65600/70000, Loss: 0.003250
# Feedback Loop Epoch 65650/70000, Loss: 0.003244
# Feedback Loop Epoch 65700/70000, Loss: 0.003239
# Feedback Loop Epoch 65750/70000, Loss: 0.003236
# Feedback Loop Epoch 65800/70000, Loss: 0.003232
# Feedback Loop Epoch 65850/70000, Loss: 0.003230
# Feedback Loop Epoch 65900/70000, Loss: 0.004082
# Feedback Loop Epoch 65950/70000, Loss: 0.003241
# Feedback Loop Epoch 66000/70000, Loss: 0.003234
# Feedback Loop Epoch 66050/70000, Loss: 0.003230
# Feedback Loop Epoch 66100/70000, Loss: 0.003226
# Feedback Loop Epoch 66150/70000, Loss: 0.003223
# Feedback Loop Epoch 66200/70000, Loss: 0.003220
# Feedback Loop Epoch 66250/70000, Loss: 0.003256
# Feedback Loop Epoch 66300/70000, Loss: 0.003231
# Feedback Loop Epoch 66350/70000, Loss: 0.003224
# Feedback Loop Epoch 66400/70000, Loss: 0.003220
# Feedback Loop Epoch 66450/70000, Loss: 0.003217
# Feedback Loop Epoch 66500/70000, Loss: 0.003214
# Feedback Loop Epoch 66550/70000, Loss: 0.003211
# Feedback Loop Epoch 66600/70000, Loss: 0.003236
# Feedback Loop Epoch 66650/70000, Loss: 0.003221
# Feedback Loop Epoch 66700/70000, Loss: 0.003216
# Feedback Loop Epoch 66750/70000, Loss: 0.003211
# Feedback Loop Epoch 66800/70000, Loss: 0.003208
# Feedback Loop Epoch 66850/70000, Loss: 0.003205
# Feedback Loop Epoch 66900/70000, Loss: 0.003202
# Feedback Loop Epoch 66950/70000, Loss: 0.003239
# Feedback Loop Epoch 67000/70000, Loss: 0.003211
# Feedback Loop Epoch 67050/70000, Loss: 0.003206
# Feedback Loop Epoch 67100/70000, Loss: 0.003202
# Feedback Loop Epoch 67150/70000, Loss: 0.003199
# Feedback Loop Epoch 67200/70000, Loss: 0.003196
# Feedback Loop Epoch 67250/70000, Loss: 0.003194
# Feedback Loop Epoch 67300/70000, Loss: 0.003216
# Feedback Loop Epoch 67350/70000, Loss: 0.003204
# Feedback Loop Epoch 67400/70000, Loss: 0.003199
# Feedback Loop Epoch 67450/70000, Loss: 0.003195
# Feedback Loop Epoch 67500/70000, Loss: 0.003192
# Feedback Loop Epoch 67550/70000, Loss: 0.003189
# Feedback Loop Epoch 67600/70000, Loss: 0.003186
# Feedback Loop Epoch 67650/70000, Loss: 0.003624
# Feedback Loop Epoch 67700/70000, Loss: 0.003196
# Feedback Loop Epoch 67750/70000, Loss: 0.003190
# Feedback Loop Epoch 67800/70000, Loss: 0.003186
# Feedback Loop Epoch 67850/70000, Loss: 0.003183
# Feedback Loop Epoch 67900/70000, Loss: 0.003180
# Feedback Loop Epoch 67950/70000, Loss: 0.003178
# Feedback Loop Epoch 68000/70000, Loss: 0.003834
# Feedback Loop Epoch 68050/70000, Loss: 0.003193
# Feedback Loop Epoch 68100/70000, Loss: 0.003184
# Feedback Loop Epoch 68150/70000, Loss: 0.003180
# Feedback Loop Epoch 68200/70000, Loss: 0.003176
# Feedback Loop Epoch 68250/70000, Loss: 0.003173
# Feedback Loop Epoch 68300/70000, Loss: 0.003171
# Feedback Loop Epoch 68350/70000, Loss: 0.003356
# Feedback Loop Epoch 68400/70000, Loss: 0.003183
# Feedback Loop Epoch 68450/70000, Loss: 0.003175
# Feedback Loop Epoch 68500/70000, Loss: 0.003171
# Feedback Loop Epoch 68550/70000, Loss: 0.003168
# Feedback Loop Epoch 68600/70000, Loss: 0.003165
# Feedback Loop Epoch 68650/70000, Loss: 0.003162
# Feedback Loop Epoch 68700/70000, Loss: 0.003576
# Feedback Loop Epoch 68750/70000, Loss: 0.003178
# Feedback Loop Epoch 68800/70000, Loss: 0.003170
# Feedback Loop Epoch 68850/70000, Loss: 0.003165
# Feedback Loop Epoch 68900/70000, Loss: 0.003162
# Feedback Loop Epoch 68950/70000, Loss: 0.003159
# Feedback Loop Epoch 69000/70000, Loss: 0.003157
# Feedback Loop Epoch 69050/70000, Loss: 0.003155
# Feedback Loop Epoch 69100/70000, Loss: 0.003210
# Feedback Loop Epoch 69150/70000, Loss: 0.003162
# Feedback Loop Epoch 69200/70000, Loss: 0.003157
# Feedback Loop Epoch 69250/70000, Loss: 0.003154
# Feedback Loop Epoch 69300/70000, Loss: 0.003151
# Feedback Loop Epoch 69350/70000, Loss: 0.003149
# Feedback Loop Epoch 69400/70000, Loss: 0.003165
# Feedback Loop Epoch 69450/70000, Loss: 0.003167
# Feedback Loop Epoch 69500/70000, Loss: 0.003159
# Feedback Loop Epoch 69550/70000, Loss: 0.003153
# Feedback Loop Epoch 69600/70000, Loss: 0.003149
# Feedback Loop Epoch 69650/70000, Loss: 0.003146
# Feedback Loop Epoch 69700/70000, Loss: 0.003144
# Feedback Loop Epoch 69750/70000, Loss: 0.003141
# Feedback Loop Epoch 69800/70000, Loss: 0.003140
# Feedback Loop Epoch 69850/70000, Loss: 0.003173
# Feedback Loop Epoch 69900/70000, Loss: 0.003147
# Feedback Loop Epoch 69950/70000, Loss: 0.003143
# Feedback Loop Epoch 70000/70000, Loss: 0.003139
# --- Feedback Loop Training Finished ---
#
# --- Generating final predictions for train and test sets ---
